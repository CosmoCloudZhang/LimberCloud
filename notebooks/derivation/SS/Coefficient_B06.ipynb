# %% [markdown]
# # SS: Coefficient B06
#
# Readable edition of the original Mathematica derivation. Scientific cells remain in source order. Normalized power uses $p=1-P_1/P_2$ in the reading edition; original spellings and complete source cells are preserved in the appendix. Cached Wolfram outputs are transcribed results, not a fresh execution.
#
# [Original Mathematica notebook](Coefficient_B06.nb) · [Conversion inventory and notation ledger](../README.md)
#
# The displayed dimensional integrals, definitions, normalized I/J integrals, inputs and outputs follow the author's original sequence. No runtime data or Mathematica installation is needed to read this notebook.

# %% [markdown]
# **Verified notation note.** The dimensional observer display refers to J7, while its integral, input, export and implementations use J6. The reading edition corrects that cross-reference to J6.

# %% [markdown]
# [Source cell 1](#source-01), `InlineFormula`.
#
# $$
# B^{i = n+1 < N, n+1<j = k < N}_{\kappa \kappa, n}=B^{n+1<i = k < N, j = n+1 < N}_{\kappa \kappa,n}= \frac{9 \Omega_{\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \int_{\chi_{n}}^{\chi_{n + 1}} \mathrm{d} \chi  \left( \frac{\chi_{n + 2}-\chi_{n + 1}}{2}-\frac{\chi \chi_{n + 2}}{\chi_{n + 2}-\chi_{n + 1}}\ln{\frac{\chi_{n + 2}}{\chi_{n + 1}}}+\frac{\chi_{n + 1}^2-2\chi_{n}\chi_{n + 1}+\chi^2}{2\left( \chi_{n + 1}-\chi_{n}  \right)}+\frac{\chi \chi_{n}}{\chi_{n + 1}-\chi_{n}}\ln{\frac{\chi_{n + 1}}{\chi}} \right)
# \left(\frac{\chi_{k+1}-\chi_{k-1}}{2}-\frac{\chi\chi_{k+1}}{\chi_{k+1}-\chi_{k}}\ln{\frac{\chi_{k+1}}{\chi_{k}}}+\frac{\chi\chi_{k-1}}{\chi_{k}-\chi_{k-1}}\ln{\frac{\chi_{k}}{\chi_{k-1}}}\right)
#  \left( \frac{\chi_{n + 1} - \chi}{\chi_{n + 1} - \chi_n} P_\ell^{n} + \frac{\chi - \chi_n}{\chi_{n + 1} - \chi_n} P_\ell^{n + 1} \right) \left(1 + \frac{\chi_{n + 1} - \chi}{\chi_{n + 1} - \chi_n} z_{n} + \frac{\chi - \chi_{n}}{\chi_{n + 1} - \chi_{n}} z_{n + 1} \right)^2
# $$

# %% [markdown]
# [Source cell 2](#source-02), `InlineFormula`.
#
# $$
# B^{i = 1, 1<j = k < N}_{\kappa \kappa, 0}=B^{1<i = k < N, j = 1}_{\kappa \kappa,0}= \frac{9 \Omega_{\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \int_{0}^{\chi_{1}} \mathrm{d} \chi  \left( \frac{\chi_{2}-\chi_{1}}{2}-\frac{\chi \chi_{2}}{\chi_{2}-\chi_{1}}\ln{\frac{\chi_{2}}{\chi_{1}}}+\frac{\chi_{1}^2+\chi^2}{2 \chi_{1}} \right)
# \left(\frac{\chi_{k+1}-\chi_{k-1}}{2}-\frac{\chi\chi_{k+1}}{\chi_{k+1}-\chi_{k}}\ln{\frac{\chi_{k+1}}{\chi_{k}}}+\frac{\chi\chi_{k-1}}{\chi_{k}-\chi_{k-1}}\ln{\frac{\chi_{k}}{\chi_{k-1}}}\right)
#  \left( \frac{\chi^3}{\chi_{1}^3}P_\ell^{1} \right) \left(1  + \frac{\chi }{\chi_{1}} z_{1} \right)^2
# $$

# %% [markdown]
# [Source cell 3](#source-03), `InlineFormula`.
#
# $$
# t = \frac{\chi}{\chi_{n + 1}}
# $$
#
# $$
# p = \frac{P_\ell ^{n + 1}- P_\ell^{n}}{P_\ell^{n + 1}}
# $$
#
# $$
# z = \frac{z_{n + 1}- z_{n}}{1 + z_{n + 1}}
# $$
#
# $$
# a = \frac{\chi_{n + 1}- \chi_{n}}{\chi_{n + 1}}
# $$
#
# $$
# b = \frac{\chi_{n + 2}- \chi_{n + 1}}{\chi_{n + 1}}
# $$
#
# $$
# c = \frac{\chi_{k + 1}-\chi_{k - 1}}{2\chi_{n + 1}}
# $$
#
# $$
# d=\frac{\chi_{k - 1}}{\chi_{k}-\chi_{k - 1}} \ln{\frac{\chi_{k}}{\chi_{k - 1}}}-\frac{\chi_{k + 1}}{\chi_{k +1}-\chi_{k}} \ln{\frac{\chi_{k+1}}{\chi_{k}}}
# $$

# %% [markdown]
# [Source cell 4](#source-04), `InlineFormula`.
#
# $$
# B^{i = n+1 < N, n+1<j = k < N}_{\kappa \kappa, n}=B^{n+1<i = k < N, j = n+1 < N}_{\kappa \kappa, n} = \frac{9 \Omega_{\mathrm{m}, 0}^2 H_0^4}{4 c^4} \chi^3_{n + 1} P_\ell^{n + 1} (1 + z_{n + 1})^2 I_6
# $$

# %% [markdown]
# [Source cell 5](#source-05), `InlineFormula`.
#
# $$
# B^{i = 1, 1<j = k < N}_{\kappa \kappa, 0}=B^{1<i = k < N, j = 1 }_{\kappa \kappa, 0} = \frac{9 \Omega_{\mathrm{m}, 0}^2 H_0^4}{4 c^4} \chi^3_{1} P_\ell^{1} (1 + z_{1})^2 J_6
# $$

# %% [markdown]
# [Source cell 6](#source-06), `InlineFormula`.
#
# $$
# I_6 = \int_{1-a}^{1} \mathrm{d} t \:  \left( \frac{b}{2}-\frac{t \left( b+1\right)}{b} \ln{\left( b+1 \right)} + 1 - \frac{1 - t^2}{2a}-\frac{t \left(  1-a \right) }{a} \ln{t}  \right) \left(  c + d t \right) \left( 1 - \frac{p}{a} (1 - t) \right) \left( 1 - \frac{z}{a} (1 - t) \right)^2
# $$

# %% [markdown]
# [Source cell 7](#source-07), `InlineFormula`.
#
# $$
# J_6 = \int_{0}^{1} \mathrm{d} t \:  \left( \frac{b}{2}-\frac{t \left( b+1\right)}{b} \ln{\left( b+1 \right)}+\frac{1+t^2}{2} \right) \left(  c + d t \right) t^3 \left( 1 - z (1 - t) \right)^2
# $$

# %% [markdown]
# ### Symbolic input
#
# [Source cell 8](#source-08), `Input`.
#
# Corrected notation; Wolfram Language shown as text.
#
# ```wolfram
# I6= FullSimplify[Integrate[((b)/(2)-(t (b+1))/(b) Log[b+1]+1-(1 - (t)^(2))/(2 a)-(t(1-a))/(a)Log[t])(c+d t)(1-(p)/(a)(1-t))((1-(z)/(a)(1-t)))^(2),{t,1-a,1},Assumptions->Element[{a,b,c,d,p,z},Reals]&&{a,p,z}<1]]
# ```

# %% [markdown]
# ### Saved symbolic output
#
# [Source cell 9](#source-09), `Output`.
#
# Transcribed cached result, with the noted symbol renaming only.
#
# $$
# \frac{1}{25200\,{a}^{4}\,b}(a\,b\,(-420\,(3\,c+d)\,p\,{z}^{2}+70\,{a}^{2}\,(-30\,(2\,c+d)\,p-6\,(5\,c\,(4+p)+2\,d\,(5+p))\,z+(d\,(-6+p)+3\,c\,(-5+p))\,{z}^{2})+210\,a\,z\,(8\,d\,p+10\,c\,z+d\,(4+p)\,z+c\,p\,(20+3\,z))+{a}^{6}\,d\,(-5950+4095\,p+42\,(195-74\,z)\,z+4\,p\,z\,(-1554+625\,z))+35\,{a}^{3}\,(c\,(60\,(6+p)-20\,(-6+p)\,z+(-10+3\,p)\,{z}^{2})+d\,(240-4\,(-15+z)\,z+p\,(30+(-8+z)\,z)))+7\,{a}^{5}\,(c\,(1500-850\,p+6\,p\,(195-74\,z)\,z+5\,z\,(-340+117\,z))+d\,(-25\,(-64+35\,p+70\,z)+2\,z\,(p\,(594-224\,z)+297\,z)+30\,b\,(-30+20\,p+5\,(8-3\,z)\,z+6\,p\,z\,(-5+2\,z))))+7\,{a}^{4}\,(d\,(50\,(-12+p)-20\,(-5+p)\,z+(-10+3\,p)\,{z}^{2}-150\,b\,(-4\,(3+(-3+z)\,z)+p\,(6+z\,(-8+3\,z))))+c\,(100\,(-9+p+2\,z)+z\,(-25\,z+p\,(-50+9\,z))-150\,b\,(-4\,(3+(-3+z)\,z)+p\,(6+z\,(-8+3\,z))))))-420\,({(-1+a)}^{3}\,b\,(5\,{a}^{2}\,(6\,a\,c-4\,(-1+a)\,a\,d-((2+4\,a)\,c+d+(2-3\,a)\,a\,d)\,p)+2\,a\,(-10\,a\,(1+2\,a)\,c+5\,(-1+a)\,a\,(1+3\,a)\,d+5\,(1+a\,(2+3\,a))\,c\,p-2\,(-1+a)\,(1+3\,a+6\,{a}^{2})\,d\,p)\,z+(a\,(5\,(1+a\,(2+3\,a))\,c-2\,(-1+a)\,(1+3\,a+6\,{a}^{2})\,d)-(3\,(1+a\,(2+a\,(3+4\,a)))\,c+d+a\,(2+a\,(3+2\,(2-5\,a)\,a))\,d)\,p)\,{z}^{2})\,\log [1-a]+{a}^{5}\,(1+b)\,(d\,(20\,(3+(-3+a)\,a)-5\,(6+a\,(-8+3\,a))\,p+2\,(-30+5\,(8-3\,a)\,a+20\,p+6\,a\,(-5+2\,a)\,p)\,z+(20-15\,p+2\,a\,(-15+6\,a+12\,p-5\,a\,p))\,{z}^{2})+c\,(20\,(3+(-3+z)\,z)+a\,(-30+20\,p+5\,(8-3\,z)\,z+6\,p\,z\,(-5+2\,z))-5\,p\,(6+z\,(-8+3\,z))))\,\log [1+b]))
# $$

# %% [markdown]
# ### Symbolic input
#
# [Source cell 10](#source-10), `Input`.
#
# Corrected notation; Wolfram Language shown as text.
#
# ```wolfram
# J6= FullSimplify[Integrate[((b)/(2)-(t (b+1))/(b) Log[b+1]+(1 + (t)^(2))/(2))(c+d t)((t)^(3))((1-z(1-t)))^(2),{t,0,1},Assumptions->Element[{b,c,d,z},Reals]&&{z}<1]]
# ```

# %% [markdown]
# ### Saved symbolic output
#
# [Source cell 11](#source-11), `Output`.
#
# Transcribed cached result, with the noted symbol renaming only.
#
# $$
# \frac{b\,(2\,d\,(432+z\,(-129+17\,z)+12\,b\,(21+(-7+z)\,z))+3\,c\,(350+z\,(-124+19\,z)+14\,b\,(15+(-6+z)\,z)))-6\,(1+b)\,(5\,d\,(28+(-8+z)\,z)+8\,c\,(21+(-7+z)\,z))\,\log [1+b]}{5040\,b}
# $$

# %% [markdown]
# ## Exact original content cells
#
# All source content cells follow in their original order, including original spellings, assumptions, saved outputs and cell metadata. Frontend-level metadata remains in the unchanged `.nb` file. Expand an entry to inspect its Wolfram box source.

# %% [markdown]
# <a id="source-01"></a>
#
# <details>
# <summary>Original source cell 1; InlineFormula; source line 21; group 1</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["k", "TI"], "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["k", "TI"], "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Integral]",
#          SubscriptBox["\[Chi]",
#           StyleBox["n", "TI"]],
#          SubscriptBox["\[Chi]",
#           RowBox[{
#             StyleBox["n", "TI"], "+", "1"}]]],
#         StyleBox["d", FontSlant -> "Plain"], "\[Chi]",
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "2"}]], "-",
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]]}], "2"], "-",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "2"}]],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "2"}]], "-",
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "2"}]],
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]]], "+",
#             FractionBox[
#              RowBox[{
#                SubsuperscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}], "2"], "-", "2",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]],
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "+",
#                SuperscriptBox["\[Chi]", "2"]}],
#              RowBox[{"2", "(",
#                RowBox[{
#                  SubscriptBox["\[Chi]",
#                   RowBox[{
#                     StyleBox["n", "TI"], "+", "1"}]], "-",
#                  SubscriptBox["\[Chi]",
#                   StyleBox["n", "TI"]]}], ")"}]], "+",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]",
#               StyleBox["n", "TI"]],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]], "\[Chi]"]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["k", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["k", "TI"], "-", "1"}]]}], "2"], "-",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]",
#               RowBox[{
#                 StyleBox["k", "TI"], "+", "1"}]],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["k", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["k", "TI"]]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["k", "TI"], "+", "1"}]],
#              SubscriptBox["\[Chi]",
#               StyleBox["k", "TI"]]], "+",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]",
#               RowBox[{
#                 StyleBox["k", "TI"], "-", "1"}]],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 StyleBox["k", "TI"]], "-",
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["k", "TI"], "-", "1"}]]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]",
#               StyleBox["k", "TI"]],
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["k", "TI"], "-", "1"}]]]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-", "\[Chi]"}],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}]],
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              StyleBox["n", "TI"]], "+",
#             FractionBox[
#              RowBox[{"\[Chi]", "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}]],
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}], ")"}],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              FractionBox[
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-", "\[Chi]"}],
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}]],
#              SubscriptBox[
#               StyleBox["z", "TI"],
#               StyleBox["n", "TI"]], "+",
#              FractionBox[
#               RowBox[{"\[Chi]", "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}],
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}]],
#              SubscriptBox[
#               StyleBox["z", "TI"],
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]]}], ")"}], "2"]}],
#       TraditionalForm], "errors" -> {}, "input" ->
#     "B^{i = n+1 < N, n+1<j = k < N}_{\\kappa \\kappa, n}=B^{n+1<i = k < N, j \
# = n+1 < N}_{\\kappa \\kappa,n}= \\frac{9 \\Omega_{\\mathrm{m}, 0}^2 H_ 0^4}{4 \
# c^4} \\int_{\\chi_{n}}^{\\chi_{n + 1}} \\mathrm{d} \\chi  \\left( \
# \\frac{\\chi_{n + 2}-\\chi_{n + 1}}{2}-\\frac{\\chi \\chi_{n + 2}}{\\chi_{n + \
# 2}-\\chi_{n + 1}}\\ln{\\frac{\\chi_{n + 2}}{\\chi_{n + 1}}}+\\frac{\\chi_{n + \
# 1}^2-2\\chi_{n}\\chi_{n + 1}+\\chi^2}{2\\left( \\chi_{n + 1}-\\chi_{n}  \
# \\right)}+\\frac{\\chi \\chi_{n}}{\\chi_{n + \
# 1}-\\chi_{n}}\\ln{\\frac{\\chi_{n + 1}}{\\chi}} \\right)\n\
# \\left(\\frac{\\chi_{k+1}-\\chi_{k-1}}{2}-\\frac{\\chi\\chi_{k+1}}{\\chi_{k+1}\
# -\\chi_{k}}\\ln{\\frac{\\chi_{k+1}}{\\chi_{k}}}+\\frac{\\chi\\chi_{k-1}}{\\\
# chi_{k}-\\chi_{k-1}}\\ln{\\frac{\\chi_{k}}{\\chi_{k-1}}}\\right)\n \\left( \
# \\frac{\\chi_{n + 1} - \\chi}{\\chi_{n + 1} - \\chi_n} P_\\ell^{n} + \
# \\frac{\\chi - \\chi_n}{\\chi_{n + 1} - \\chi_n} P_\\ell^{n + 1} \\right) \
# \\left(1 + \\frac{\\chi_{n + 1} - \\chi}{\\chi_{n + 1} - \\chi_n} z_{n} + \
# \\frac{\\chi - \\chi_{n}}{\\chi_{n + 1} - \\chi_{n}} z_{n + 1} \\right)^2",
#     "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"7ac3d43b-6434-4ef7-81c7-2840e88764ba"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.9757831945616693`*^9},ExpressionUUID->"d0d1126f-5d02-4d1e-88de-\
# de9f6b677ea5"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-02"></a>
#
# <details>
# <summary>Original source cell 2; InlineFormula; source line 252; group 2</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",", "0"}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]", "1", ",", "1", "<",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["k", "TI"], "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",", "0"}],
#          RowBox[{"1", "<",
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["k", "TI"], "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]", "1"}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Integral]", "0",
#          SubscriptBox["\[Chi]", "1"]],
#         StyleBox["d", FontSlant -> "Plain"], "\[Chi]",
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubscriptBox["\[Chi]", "2"], "-",
#                SubscriptBox["\[Chi]", "1"]}], "2"], "-",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]", "2"],
#              RowBox[{
#                SubscriptBox["\[Chi]", "2"], "-",
#                SubscriptBox["\[Chi]", "1"]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]", "2"],
#              SubscriptBox["\[Chi]", "1"]], "+",
#             FractionBox[
#              RowBox[{
#                SubsuperscriptBox["\[Chi]", "1", "2"], "+",
#                SuperscriptBox["\[Chi]", "2"]}],
#              RowBox[{"2",
#                SubscriptBox["\[Chi]", "1"]}]]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["k", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["k", "TI"], "-", "1"}]]}], "2"], "-",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]",
#               RowBox[{
#                 StyleBox["k", "TI"], "+", "1"}]],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["k", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["k", "TI"]]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["k", "TI"], "+", "1"}]],
#              SubscriptBox["\[Chi]",
#               StyleBox["k", "TI"]]], "+",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]",
#               RowBox[{
#                 StyleBox["k", "TI"], "-", "1"}]],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 StyleBox["k", "TI"]], "-",
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["k", "TI"], "-", "1"}]]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]",
#               StyleBox["k", "TI"]],
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["k", "TI"], "-", "1"}]]]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              SuperscriptBox["\[Chi]", "3"],
#              SubsuperscriptBox["\[Chi]", "1", "3"]],
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]", "1"]}], ")"}],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              FractionBox["\[Chi]",
#               SubscriptBox["\[Chi]", "1"]],
#              SubscriptBox[
#               StyleBox["z", "TI"], "1"]}], ")"}], "2"]}], TraditionalForm],
#     "errors" -> {}, "input" ->
#     "B^{i = 1, 1<j = k < N}_{\\kappa \\kappa, 0}=B^{1<i = k < N, j = \
# 1}_{\\kappa \\kappa,0}= \\frac{9 \\Omega_{\\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \
# \\int_{0}^{\\chi_{1}} \\mathrm{d} \\chi  \\left( \
# \\frac{\\chi_{2}-\\chi_{1}}{2}-\\frac{\\chi \
# \\chi_{2}}{\\chi_{2}-\\chi_{1}}\\ln{\\frac{\\chi_{2}}{\\chi_{1}}}+\\frac{\\\
# chi_{1}^2+\\chi^2}{2 \\chi_{1}} \\right)\n\
# \\left(\\frac{\\chi_{k+1}-\\chi_{k-1}}{2}-\\frac{\\chi\\chi_{k+1}}{\\chi_{k+1}\
# -\\chi_{k}}\\ln{\\frac{\\chi_{k+1}}{\\chi_{k}}}+\\frac{\\chi\\chi_{k-1}}{\\\
# chi_{k}-\\chi_{k-1}}\\ln{\\frac{\\chi_{k}}{\\chi_{k-1}}}\\right)\n \\left( \
# \\frac{\\chi^3}{\\chi_{1}^3}P_\\ell^{1} \\right) \\left(1  + \\frac{\\chi \
# }{\\chi_{1}} z_{1} \\right)^2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"a2752f57-9dba-419c-8f53-40bc2ea3cbc5"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.975783213356022*^9},ExpressionUUID->"ebf6aacf-e7d7-41d8-8dba-\
# da13b6f95c9c"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-03"></a>
#
# <details>
# <summary>Original source cell 3; InlineFormula; source line 380; group 3</summary>
#
# ```wolfram
# Cell[TextData[{
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["t", "TI"], "\[LongEqual]",
#          FractionBox["\[Chi]",
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" -> "t = \\frac{\\chi}{\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "4912d5c3-8324-4d69-b599-aa8184e5949f"],
#  ",  ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["p", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]], "-",
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              StyleBox["n", "TI"]]}],
#           SubsuperscriptBox[
#            StyleBox["P", "TI"], "\[ScriptL]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "p = \\frac{P_\\ell ^{n + 1}- P_\\ell^{n}}{P_\\ell^{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "2eee0d46-505d-4d0b-a58e-a80e9d4b755e"],
#  ", ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["z", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox[
#              StyleBox["z", "TI"],
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]], "-",
#             SubscriptBox[
#              StyleBox["z", "TI"],
#              StyleBox["n", "TI"]]}],
#           RowBox[{"1", "+",
#             SubscriptBox[
#              StyleBox["z", "TI"],
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}]]}], TraditionalForm],
#      "errors" -> {}, "input" -> "z = \\frac{z_{n + 1}- z_{n}}{1 + z_{n + 1}}",
#       "state" -> "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "be8b5f05-d2fa-477e-8c94-d8b2004eff86"],
#  ", ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["a", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]], "-",
#             SubscriptBox["\[Chi]",
#              StyleBox["n", "TI"]]}],
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "a = \\frac{\\chi_{n + 1}- \\chi_{n}}{\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "5ef77fdc-ebad-4509-b4c7-84cce882eb7f"],
#  ",",
#  StyleBox[" ",
#   FontWeight->"Bold"],
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["b", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "2"}]], "-",
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}],
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "b = \\frac{\\chi_{n + 2}- \\chi_{n + 1}}{\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "ce760377-6b1a-44ec-9037-03984fbdc85d"],
#  ",",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["c", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["k", "TI"], "+", "1"}]], "-",
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["k", "TI"], "-", "1"}]]}],
#           RowBox[{"2",
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "c = \\frac{\\chi_{k + 1}-\\chi_{k - 1}}{2\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "0e2c2f5f-8e87-4a36-8bd7-3663d617e059"],
#  ", ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["d", "TI"], "\[LongEqual]",
#          FractionBox[
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["k", "TI"], "-", "1"}]],
#           RowBox[{
#             SubscriptBox["\[Chi]",
#              StyleBox["k", "TI"]], "-",
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["k", "TI"], "-", "1"}]]}]], "ln",
#          FractionBox[
#           SubscriptBox["\[Chi]",
#            StyleBox["k", "TI"]],
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["k", "TI"], "-", "1"}]]], "-",
#          FractionBox[
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["k", "TI"], "+", "1"}]],
#           RowBox[{
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["k", "TI"], "+", "1"}]], "-",
#             SubscriptBox["\[Chi]",
#              StyleBox["k", "TI"]]}]], "ln",
#          FractionBox[
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["k", "TI"], "+", "1"}]],
#           SubscriptBox["\[Chi]",
#            StyleBox["k", "TI"]]]}], TraditionalForm], "errors" -> {}, "input" ->
#      "d=\\frac{\\chi_{k - 1}}{\\chi_{k}-\\chi_{k - 1}} \
# \\ln{\\frac{\\chi_{k}}{\\chi_{k - 1}}}-\\frac{\\chi_{k + 1}}{\\chi_{k \
# +1}-\\chi_{k}} \\ln{\\frac{\\chi_{k+1}}{\\chi_{k}}}", "state" -> "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "421fe2c5-34ff-496a-ab19-4dc2489c2fa1"]
# }], "InlineFormula",
#  CellChangeTimes->{{3.887196302307176*^9, 3.887196331440764*^9}, {
#    3.887196362536772*^9, 3.887196382134186*^9}, {3.9084206984864616`*^9,
#    3.9084207040669937`*^9}, 3.9084340401865296`*^9, 3.9084351731002855`*^9,
#    3.9084355812628045`*^9, 3.9084393806834965`*^9, 3.908439450532996*^9, {
#    3.908931098910103*^9,
#    3.9089311045811234`*^9}},ExpressionUUID->"7b6246ea-d307-486a-90da-\
# c05c2c9b0953"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-04"></a>
#
# <details>
# <summary>Original source cell 4; InlineFormula; source line 562; group 4</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["k", "TI"], "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["k", "TI"], "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Chi]",
#          RowBox[{
#            StyleBox["n", "TI"], "+", "1"}], "3"],
#         SubsuperscriptBox[
#          StyleBox["P", "TI"], "\[ScriptL]",
#          RowBox[{
#            StyleBox["n", "TI"], "+", "1"}]],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              SubscriptBox[
#               StyleBox["z", "TI"],
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]]}], ")"}], "2"],
#         SubscriptBox[
#          StyleBox["I", "TI"], "6"]}], TraditionalForm], "errors" -> {},
#     "input" ->
#     "B^{i = n+1 < N, n+1<j = k < N}_{\\kappa \\kappa, n}=B^{n+1<i = k < N, j \
# = n+1 < N}_{\\kappa \\kappa, n} = \\frac{9 \\Omega_{\\mathrm{m}, 0}^2 \
# H_0^4}{4 c^4} \\chi^3_{n + 1} P_\\ell^{n + 1} (1 + z_{n + 1})^2 I_6", "state" ->
#     "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"042353f9-a993-4e9b-847c-3ce95bebc683"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196401920412*^9, {3.9084337680750885`*^9,
#    3.908433770987523*^9}},ExpressionUUID->"21cd44dd-49c8-44f7-a1b3-\
# e5707dd0452b"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-05"></a>
#
# <details>
# <summary>Original source cell 5; InlineFormula; source line 629; group 5</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",", "0"}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]", "1", ",", "1", "<",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["k", "TI"], "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",", "0"}],
#          RowBox[{"1", "<",
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["k", "TI"], "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]", "1"}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Chi]", "1", "3"],
#         SubsuperscriptBox[
#          StyleBox["P", "TI"], "\[ScriptL]", "1"],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              SubscriptBox[
#               StyleBox["z", "TI"], "1"]}], ")"}], "2"],
#         SubscriptBox[
#          StyleBox["J", "TI"], "7"]}], TraditionalForm], "errors" -> {},
#     "input" ->
#     "B^{i = 1, 1<j = k < N}_{\\kappa \\kappa, 0}=B^{1<i = k < N, j = 1 \
# }_{\\kappa \\kappa, 0} = \\frac{9 \\Omega_{\\mathrm{m}, 0}^2 H_0^4}{4 c^4} \
# \\chi^3_{1} P_\\ell^{1} (1 + z_{1})^2 J_7", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"aa9c13ea-caa1-446e-9e63-a9cd97c48faf"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196401920412*^9, {3.9084337680750885`*^9,
#    3.908433770987523*^9}},ExpressionUUID->"94f17875-2b58-4ff3-b3a0-\
# 56f6f501623e"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-06"></a>
#
# <details>
# <summary>Original source cell 6; InlineFormula; source line 681; group 6</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubscriptBox[
#          StyleBox["I", "TI"], "6"], "\[LongEqual]",
#         SubsuperscriptBox["\[Integral]",
#          RowBox[{"1", "-",
#            StyleBox["a", "TI"]}], "1"],
#         StyleBox["d", FontSlant -> "Plain"],
#         StyleBox["t", "TI"], " ",
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              StyleBox["b", "TI"], "2"], "-",
#             FractionBox[
#              RowBox[{
#                StyleBox["t", "TI"], "(",
#                RowBox[{
#                  StyleBox["b", "TI"], "+", "1"}], ")"}],
#              StyleBox["b", "TI"]], "ln",
#             RowBox[{"(",
#               RowBox[{
#                 StyleBox["b", "TI"], "+", "1"}], ")"}], "+", "1", "-",
#             FractionBox[
#              RowBox[{"1", "-",
#                SuperscriptBox[
#                 StyleBox["t", "TI"], "2"]}],
#              RowBox[{"2",
#                StyleBox["a", "TI"]}]], "-",
#             FractionBox[
#              RowBox[{
#                StyleBox["t", "TI"], "(",
#                RowBox[{"1", "-",
#                  StyleBox["a", "TI"]}], ")"}],
#              StyleBox["a", "TI"]], "ln",
#             StyleBox["t", "TI"]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             StyleBox["c", "TI"], "+",
#             StyleBox["d", "TI"],
#             StyleBox["t", "TI"]}], ")"}],
#         RowBox[{"(",
#           RowBox[{"1", "-",
#             FractionBox[
#              StyleBox["p", "TI"],
#              StyleBox["a", "TI"]],
#             RowBox[{"(",
#               RowBox[{"1", "-",
#                 StyleBox["t", "TI"]}], ")"}]}], ")"}],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "-",
#              FractionBox[
#               StyleBox["z", "TI"],
#               StyleBox["a", "TI"]],
#              RowBox[{"(",
#                RowBox[{"1", "-",
#                  StyleBox["t", "TI"]}], ")"}]}], ")"}], "2"]}],
#       TraditionalForm], "errors" -> {}, "input" ->
#     "I_6 = \\int_{1-a}^{1} \\mathrm{d} t \\:  \\left( \\frac{b}{2}-\\frac{t \
# \\left( b+1\\right)}{b} \\ln{\\left( b+1 \\right)} + 1 - \\frac{1 - t^2}{2a}-\
# \\frac{t \\left(  1-a \\right) }{a} \\ln{t}  \\right) \\left(  c + d t \
# \\right) \\left( 1 - \\frac{p}{a} (1 - t) \\right) \\left( 1 - \\frac{z}{a} \
# (1 - t) \\right)^2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"f8d8d33b-26e6-44a7-ab4c-a2f5f26c6a82"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196539368146*^9},ExpressionUUID->"2e461cf4-f0f3-4eef-ba1c-\
# 97aa73b03444"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-07"></a>
#
# <details>
# <summary>Original source cell 7; InlineFormula; source line 753; group 7</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubscriptBox[
#          StyleBox["J", "TI"], "6"], "\[LongEqual]",
#         SubsuperscriptBox["\[Integral]", "0", "1"],
#         StyleBox["d", FontSlant -> "Plain"],
#         StyleBox["t", "TI"], " ",
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              StyleBox["b", "TI"], "2"], "-",
#             FractionBox[
#              RowBox[{
#                StyleBox["t", "TI"], "(",
#                RowBox[{
#                  StyleBox["b", "TI"], "+", "1"}], ")"}],
#              StyleBox["b", "TI"]], "ln",
#             RowBox[{"(",
#               RowBox[{
#                 StyleBox["b", "TI"], "+", "1"}], ")"}], "+",
#             FractionBox[
#              RowBox[{"1", "+",
#                SuperscriptBox[
#                 StyleBox["t", "TI"], "2"]}], "2"]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             StyleBox["c", "TI"], "+",
#             StyleBox["d", "TI"],
#             StyleBox["t", "TI"]}], ")"}],
#         SuperscriptBox[
#          StyleBox["t", "TI"], "3"],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "-",
#              StyleBox["z", "TI"],
#              RowBox[{"(",
#                RowBox[{"1", "-",
#                  StyleBox["t", "TI"]}], ")"}]}], ")"}], "2"]}],
#       TraditionalForm], "errors" -> {}, "input" ->
#     "J_6 = \\int_{0}^{1} \\mathrm{d} t \\:  \\left( \\frac{b}{2}-\\frac{t \
# \\left( b+1\\right)}{b} \\ln{\\left( b+1 \\right)}+\\frac{1+t^2}{2} \\right) \
# \\left(  c + d t \\right) t^3 \\left( 1 - z (1 - t) \\right)^2", "state" ->
#     "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"e8e83398-c7be-437c-bc34-30fd4fd1e718"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196539368146*^9},ExpressionUUID->"b2fa8cc3-bd6c-4e39-8eca-\
# d1f22b9a60be"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-08"></a>
#
# <details>
# <summary>Original source cell 8; Input; source line 807; group 8.1</summary>
#
# ```wolfram
# Cell[BoxData[
#  RowBox[{"I6", "=", " ",
#   RowBox[{"FullSimplify", "[",
#    RowBox[{"Integrate", "[",
#     RowBox[{
#      RowBox[{
#       RowBox[{"(",
#        RowBox[{
#         FractionBox["b", "2"], "-",
#         RowBox[{
#          FractionBox[
#           RowBox[{"t", " ",
#            RowBox[{"(",
#             RowBox[{"b", "+", "1"}], ")"}]}], "b"], " ",
#          RowBox[{"Log", "[",
#           RowBox[{"b", "+", "1"}], "]"}]}], "+", "1", "-",
#         FractionBox[
#          RowBox[{"1", " ", "-", " ",
#           SuperscriptBox["t", "2"]}],
#          RowBox[{"2", " ", "a"}]], "-",
#         RowBox[{
#          FractionBox[
#           RowBox[{"t",
#            RowBox[{"(",
#             RowBox[{"1", "-", "a"}], ")"}]}], "a"],
#          RowBox[{"Log", "[", "t", "]"}]}]}], ")"}],
#       RowBox[{"(",
#        RowBox[{"c", "+",
#         RowBox[{"d", " ", "t"}]}], ")"}],
#       RowBox[{"(",
#        RowBox[{"1", "-",
#         RowBox[{
#          FractionBox["p", "a"],
#          RowBox[{"(",
#           RowBox[{"1", "-", "t"}], ")"}]}]}], ")"}],
#       SuperscriptBox[
#        RowBox[{"(",
#         RowBox[{"1", "-",
#          RowBox[{
#           FractionBox["z", "a"],
#           RowBox[{"(",
#            RowBox[{"1", "-", "t"}], ")"}]}]}], ")"}], "2"]}], ",",
#      RowBox[{"{",
#       RowBox[{"t", ",",
#        RowBox[{"1", "-", "a"}], ",", "1"}], "}"}], ",",
#      RowBox[{"Assumptions", "->",
#       RowBox[{
#        RowBox[{"Element", "[",
#         RowBox[{
#          RowBox[{"{",
#           RowBox[{"a", ",", "b", ",", "c", ",", "d", ",", "p", ",", "z"}],
#           "}"}], ",", "Reals"}], "]"}], "&&",
#        RowBox[{
#         RowBox[{"{",
#          RowBox[{"a", ",", "p", ",", "z"}], "}"}], "<", "1"}]}]}]}], "]"}],
#    "]"}]}]], "Input",
#  CellChangeTimes->{{3.8871966515420856`*^9, 3.887196657849538*^9}, {
#    3.887197019461763*^9, 3.8871970202578783`*^9}, 3.887197391169403*^9,
#    3.8876346041182613`*^9, {3.8879047776300783`*^9, 3.887904807663855*^9}, {
#    3.887904924599154*^9, 3.887904942996567*^9}, 3.888148387380184*^9, {
#    3.908436037243232*^9, 3.9084362203498116`*^9}, {3.9084386916235085`*^9,
#    3.9084387068005824`*^9}, {3.90843950027335*^9, 3.9084395118652344`*^9}, {
#    3.908440122366754*^9, 3.9084401244746466`*^9}, {3.908931115690956*^9,
#    3.908931191427043*^9}, {3.9167988585590096`*^9, 3.916798858901224*^9}, {
#    3.975783560371381*^9, 3.975783588735968*^9}},
#  CellLabel->"In[1]:=",ExpressionUUID->"43640b55-9bdb-44d4-99fa-5150f7081833"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-09"></a>
#
# <details>
# <summary>Original source cell 9; Output; source line 874; group 8.2</summary>
#
# ```wolfram
# Cell[BoxData[
#  RowBox[{
#   FractionBox["1",
#    RowBox[{"25200", " ",
#     SuperscriptBox["a", "4"], " ", "b"}]],
#   RowBox[{"(",
#    RowBox[{
#     RowBox[{"a", " ", "b", " ",
#      RowBox[{"(",
#       RowBox[{
#        RowBox[{
#         RowBox[{"-", "420"}], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"3", " ", "c"}], "+", "d"}], ")"}], " ", "p", " ",
#         SuperscriptBox["z", "2"]}], "+",
#        RowBox[{"70", " ",
#         SuperscriptBox["a", "2"], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{
#            RowBox[{"-", "30"}], " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"2", " ", "c"}], "+", "d"}], ")"}], " ", "p"}], "-",
#           RowBox[{"6", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"5", " ", "c", " ",
#               RowBox[{"(",
#                RowBox[{"4", "+", "p"}], ")"}]}], "+",
#              RowBox[{"2", " ", "d", " ",
#               RowBox[{"(",
#                RowBox[{"5", "+", "p"}], ")"}]}]}], ")"}], " ", "z"}], "+",
#           RowBox[{
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"d", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "6"}], "+", "p"}], ")"}]}], "+",
#              RowBox[{"3", " ", "c", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "5"}], "+", "p"}], ")"}]}]}], ")"}], " ",
#            SuperscriptBox["z", "2"]}]}], ")"}]}], "+",
#        RowBox[{"210", " ", "a", " ", "z", " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"8", " ", "d", " ", "p"}], "+",
#           RowBox[{"10", " ", "c", " ", "z"}], "+",
#           RowBox[{"d", " ",
#            RowBox[{"(",
#             RowBox[{"4", "+", "p"}], ")"}], " ", "z"}], "+",
#           RowBox[{"c", " ", "p", " ",
#            RowBox[{"(",
#             RowBox[{"20", "+",
#              RowBox[{"3", " ", "z"}]}], ")"}]}]}], ")"}]}], "+",
#        RowBox[{
#         SuperscriptBox["a", "6"], " ", "d", " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"-", "5950"}], "+",
#           RowBox[{"4095", " ", "p"}], "+",
#           RowBox[{"42", " ",
#            RowBox[{"(",
#             RowBox[{"195", "-",
#              RowBox[{"74", " ", "z"}]}], ")"}], " ", "z"}], "+",
#           RowBox[{"4", " ", "p", " ", "z", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"-", "1554"}], "+",
#              RowBox[{"625", " ", "z"}]}], ")"}]}]}], ")"}]}], "+",
#        RowBox[{"35", " ",
#         SuperscriptBox["a", "3"], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"c", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"60", " ",
#               RowBox[{"(",
#                RowBox[{"6", "+", "p"}], ")"}]}], "-",
#              RowBox[{"20", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "6"}], "+", "p"}], ")"}], " ", "z"}], "+",
#              RowBox[{
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "10"}], "+",
#                 RowBox[{"3", " ", "p"}]}], ")"}], " ",
#               SuperscriptBox["z", "2"]}]}], ")"}]}], "+",
#           RowBox[{"d", " ",
#            RowBox[{"(",
#             RowBox[{"240", "-",
#              RowBox[{"4", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "15"}], "+", "z"}], ")"}], " ", "z"}], "+",
#              RowBox[{"p", " ",
#               RowBox[{"(",
#                RowBox[{"30", "+",
#                 RowBox[{
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "8"}], "+", "z"}], ")"}], " ", "z"}]}],
#                ")"}]}]}], ")"}]}]}], ")"}]}], "+",
#        RowBox[{"7", " ",
#         SuperscriptBox["a", "5"], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"c", " ",
#            RowBox[{"(",
#             RowBox[{"1500", "-",
#              RowBox[{"850", " ", "p"}], "+",
#              RowBox[{"6", " ", "p", " ",
#               RowBox[{"(",
#                RowBox[{"195", "-",
#                 RowBox[{"74", " ", "z"}]}], ")"}], " ", "z"}], "+",
#              RowBox[{"5", " ", "z", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "340"}], "+",
#                 RowBox[{"117", " ", "z"}]}], ")"}]}]}], ")"}]}], "+",
#           RowBox[{"d", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{
#               RowBox[{"-", "25"}], " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "64"}], "+",
#                 RowBox[{"35", " ", "p"}], "+",
#                 RowBox[{"70", " ", "z"}]}], ")"}]}], "+",
#              RowBox[{"2", " ", "z", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"p", " ",
#                  RowBox[{"(",
#                   RowBox[{"594", "-",
#                    RowBox[{"224", " ", "z"}]}], ")"}]}], "+",
#                 RowBox[{"297", " ", "z"}]}], ")"}]}], "+",
#              RowBox[{"30", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "30"}], "+",
#                 RowBox[{"20", " ", "p"}], "+",
#                 RowBox[{"5", " ",
#                  RowBox[{"(",
#                   RowBox[{"8", "-",
#                    RowBox[{"3", " ", "z"}]}], ")"}], " ", "z"}], "+",
#                 RowBox[{"6", " ", "p", " ", "z", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "5"}], "+",
#                    RowBox[{"2", " ", "z"}]}], ")"}]}]}], ")"}]}]}], ")"}]}]}],
#           ")"}]}], "+",
#        RowBox[{"7", " ",
#         SuperscriptBox["a", "4"], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"d", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"50", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "12"}], "+", "p"}], ")"}]}], "-",
#              RowBox[{"20", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "5"}], "+", "p"}], ")"}], " ", "z"}], "+",
#              RowBox[{
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "10"}], "+",
#                 RowBox[{"3", " ", "p"}]}], ")"}], " ",
#               SuperscriptBox["z", "2"]}], "-",
#              RowBox[{"150", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"-", "4"}], " ",
#                  RowBox[{"(",
#                   RowBox[{"3", "+",
#                    RowBox[{
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "3"}], "+", "z"}], ")"}], " ", "z"}]}],
#                   ")"}]}], "+",
#                 RowBox[{"p", " ",
#                  RowBox[{"(",
#                   RowBox[{"6", "+",
#                    RowBox[{"z", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "8"}], "+",
#                     RowBox[{"3", " ", "z"}]}], ")"}]}]}], ")"}]}]}],
#                ")"}]}]}], ")"}]}], "+",
#           RowBox[{"c", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"100", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "9"}], "+", "p", "+",
#                 RowBox[{"2", " ", "z"}]}], ")"}]}], "+",
#              RowBox[{"z", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"-", "25"}], " ", "z"}], "+",
#                 RowBox[{"p", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "50"}], "+",
#                    RowBox[{"9", " ", "z"}]}], ")"}]}]}], ")"}]}], "-",
#              RowBox[{"150", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"-", "4"}], " ",
#                  RowBox[{"(",
#                   RowBox[{"3", "+",
#                    RowBox[{
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "3"}], "+", "z"}], ")"}], " ", "z"}]}],
#                   ")"}]}], "+",
#                 RowBox[{"p", " ",
#                  RowBox[{"(",
#                   RowBox[{"6", "+",
#                    RowBox[{"z", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "8"}], "+",
#                     RowBox[{"3", " ", "z"}]}], ")"}]}]}], ")"}]}]}],
#                ")"}]}]}], ")"}]}]}], ")"}]}]}], ")"}]}], "-",
#     RowBox[{"420", " ",
#      RowBox[{"(",
#       RowBox[{
#        RowBox[{
#         SuperscriptBox[
#          RowBox[{"(",
#           RowBox[{
#            RowBox[{"-", "1"}], "+", "a"}], ")"}], "3"], " ", "b", " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"5", " ",
#            SuperscriptBox["a", "2"], " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"6", " ", "a", " ", "c"}], "-",
#              RowBox[{"4", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "1"}], "+", "a"}], ")"}], " ", "a", " ", "d"}],
#              "-",
#              RowBox[{
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"(",
#                   RowBox[{"2", "+",
#                    RowBox[{"4", " ", "a"}]}], ")"}], " ", "c"}], "+", "d",
#                 "+",
#                 RowBox[{
#                  RowBox[{"(",
#                   RowBox[{"2", "-",
#                    RowBox[{"3", " ", "a"}]}], ")"}], " ", "a", " ", "d"}]}],
#                ")"}], " ", "p"}]}], ")"}]}], "+",
#           RowBox[{"2", " ", "a", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{
#               RowBox[{"-", "10"}], " ", "a", " ",
#               RowBox[{"(",
#                RowBox[{"1", "+",
#                 RowBox[{"2", " ", "a"}]}], ")"}], " ", "c"}], "+",
#              RowBox[{"5", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "1"}], "+", "a"}], ")"}], " ", "a", " ",
#               RowBox[{"(",
#                RowBox[{"1", "+",
#                 RowBox[{"3", " ", "a"}]}], ")"}], " ", "d"}], "+",
#              RowBox[{"5", " ",
#               RowBox[{"(",
#                RowBox[{"1", "+",
#                 RowBox[{"a", " ",
#                  RowBox[{"(",
#                   RowBox[{"2", "+",
#                    RowBox[{"3", " ", "a"}]}], ")"}]}]}], ")"}], " ", "c", " ",
#                "p"}], "-",
#              RowBox[{"2", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "1"}], "+", "a"}], ")"}], " ",
#               RowBox[{"(",
#                RowBox[{"1", "+",
#                 RowBox[{"3", " ", "a"}], "+",
#                 RowBox[{"6", " ",
#                  SuperscriptBox["a", "2"]}]}], ")"}], " ", "d", " ", "p"}]}],
#             ")"}], " ", "z"}], "+",
#           RowBox[{
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"a", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"5", " ",
#                  RowBox[{"(",
#                   RowBox[{"1", "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"2", "+",
#                     RowBox[{"3", " ", "a"}]}], ")"}]}]}], ")"}], " ", "c"}],
#                 "-",
#                 RowBox[{"2", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "1"}], "+", "a"}], ")"}], " ",
#                  RowBox[{"(",
#                   RowBox[{"1", "+",
#                    RowBox[{"3", " ", "a"}], "+",
#                    RowBox[{"6", " ",
#                     SuperscriptBox["a", "2"]}]}], ")"}], " ", "d"}]}],
#                ")"}]}], "-",
#              RowBox[{
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"3", " ",
#                  RowBox[{"(",
#                   RowBox[{"1", "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"2", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"3", "+",
#                     RowBox[{"4", " ", "a"}]}], ")"}]}]}], ")"}]}]}], ")"}],
#                  " ", "c"}], "+", "d", "+",
#                 RowBox[{"a", " ",
#                  RowBox[{"(",
#                   RowBox[{"2", "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"3", "+",
#                     RowBox[{"2", " ",
#                     RowBox[{"(",
#                     RowBox[{"2", "-",
#                     RowBox[{"5", " ", "a"}]}], ")"}], " ", "a"}]}], ")"}]}]}],
#                    ")"}], " ", "d"}]}], ")"}], " ", "p"}]}], ")"}], " ",
#            SuperscriptBox["z", "2"]}]}], ")"}], " ",
#         RowBox[{"Log", "[",
#          RowBox[{"1", "-", "a"}], "]"}]}], "+",
#        RowBox[{
#         SuperscriptBox["a", "5"], " ",
#         RowBox[{"(",
#          RowBox[{"1", "+", "b"}], ")"}], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"d", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"20", " ",
#               RowBox[{"(",
#                RowBox[{"3", "+",
#                 RowBox[{
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "3"}], "+", "a"}], ")"}], " ", "a"}]}],
#                ")"}]}], "-",
#              RowBox[{"5", " ",
#               RowBox[{"(",
#                RowBox[{"6", "+",
#                 RowBox[{"a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "8"}], "+",
#                    RowBox[{"3", " ", "a"}]}], ")"}]}]}], ")"}], " ", "p"}],
#              "+",
#              RowBox[{"2", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "30"}], "+",
#                 RowBox[{"5", " ",
#                  RowBox[{"(",
#                   RowBox[{"8", "-",
#                    RowBox[{"3", " ", "a"}]}], ")"}], " ", "a"}], "+",
#                 RowBox[{"20", " ", "p"}], "+",
#                 RowBox[{"6", " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "5"}], "+",
#                    RowBox[{"2", " ", "a"}]}], ")"}], " ", "p"}]}], ")"}], " ",
#                "z"}], "+",
#              RowBox[{
#               RowBox[{"(",
#                RowBox[{"20", "-",
#                 RowBox[{"15", " ", "p"}], "+",
#                 RowBox[{"2", " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "15"}], "+",
#                    RowBox[{"6", " ", "a"}], "+",
#                    RowBox[{"12", " ", "p"}], "-",
#                    RowBox[{"5", " ", "a", " ", "p"}]}], ")"}]}]}], ")"}], " ",
#               SuperscriptBox["z", "2"]}]}], ")"}]}], "+",
#           RowBox[{"c", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"20", " ",
#               RowBox[{"(",
#                RowBox[{"3", "+",
#                 RowBox[{
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "3"}], "+", "z"}], ")"}], " ", "z"}]}],
#                ")"}]}], "+",
#              RowBox[{"a", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "30"}], "+",
#                 RowBox[{"20", " ", "p"}], "+",
#                 RowBox[{"5", " ",
#                  RowBox[{"(",
#                   RowBox[{"8", "-",
#                    RowBox[{"3", " ", "z"}]}], ")"}], " ", "z"}], "+",
#                 RowBox[{"6", " ", "p", " ", "z", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "5"}], "+",
#                    RowBox[{"2", " ", "z"}]}], ")"}]}]}], ")"}]}], "-",
#              RowBox[{"5", " ", "p", " ",
#               RowBox[{"(",
#                RowBox[{"6", "+",
#                 RowBox[{"z", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "8"}], "+",
#                    RowBox[{"3", " ", "z"}]}], ")"}]}]}], ")"}]}]}], ")"}]}]}],
#           ")"}], " ",
#         RowBox[{"Log", "[",
#          RowBox[{"1", "+", "b"}], "]"}]}]}], ")"}]}]}], ")"}]}]], "Output",
#  CellChangeTimes->{{3.908421068111334*^9, 3.9084210920073547`*^9},
#    3.908436269683008*^9, 3.908438781589342*^9, 3.908439572044049*^9,
#    3.908440163532981*^9, 3.9089313829522467`*^9, 3.9095608668041973`*^9,
#    3.916798981951229*^9, 3.9168103153963394`*^9, 3.916818234403613*^9,
#    3.9168326295506344`*^9, 3.9168353431182723`*^9, 3.9170234776544886`*^9,
#    3.975783683874981*^9},
#  CellLabel->"Out[1]=",ExpressionUUID->"025e5d76-eaf8-4479-845c-2be00ddb5df3"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-10"></a>
#
# <details>
# <summary>Original source cell 10; Input; source line 1331; group 9.1</summary>
#
# ```wolfram
# Cell[BoxData[
#  RowBox[{"J6", "=", " ",
#   RowBox[{"FullSimplify", "[",
#    RowBox[{"Integrate", "[",
#     RowBox[{
#      RowBox[{
#       RowBox[{"(",
#        RowBox[{
#         FractionBox["b", "2"], "-",
#         RowBox[{
#          FractionBox[
#           RowBox[{"t", " ",
#            RowBox[{"(",
#             RowBox[{"b", "+", "1"}], ")"}]}], "b"], " ",
#          RowBox[{"Log", "[",
#           RowBox[{"b", "+", "1"}], "]"}]}], "+",
#         FractionBox[
#          RowBox[{"1", " ", "+", " ",
#           SuperscriptBox["t", "2"]}], "2"]}], ")"}],
#       RowBox[{"(",
#        RowBox[{"c", "+",
#         RowBox[{"d", " ", "t"}]}], ")"}],
#       RowBox[{"(",
#        SuperscriptBox["t", "3"], ")"}],
#       SuperscriptBox[
#        RowBox[{"(",
#         RowBox[{"1", "-",
#          RowBox[{"z",
#           RowBox[{"(",
#            RowBox[{"1", "-", "t"}], ")"}]}]}], ")"}], "2"]}], ",",
#      RowBox[{"{",
#       RowBox[{"t", ",", "0", ",", "1"}], "}"}], ",",
#      RowBox[{"Assumptions", "->",
#       RowBox[{
#        RowBox[{"Element", "[",
#         RowBox[{
#          RowBox[{"{",
#           RowBox[{"b", ",", "c", ",", "d", ",", "z"}], "}"}], ",", "Reals"}],
#         "]"}], "&&",
#        RowBox[{
#         RowBox[{"{", "z", "}"}], "<", "1"}]}]}]}], "]"}], "]"}]}]], "Input",
#  CellChangeTimes->{{3.8871966515420856`*^9, 3.887196657849538*^9}, {
#    3.887197019461763*^9, 3.8871970202578783`*^9}, 3.887197391169403*^9,
#    3.8876346041182613`*^9, {3.8879047776300783`*^9, 3.887904807663855*^9}, {
#    3.887904924599154*^9, 3.887904942996567*^9}, 3.888148387380184*^9, {
#    3.908436037243232*^9, 3.9084362203498116`*^9}, {3.9084386916235085`*^9,
#    3.9084387068005824`*^9}, {3.90843950027335*^9, 3.9084395118652344`*^9}, {
#    3.908440122366754*^9, 3.9084401244746466`*^9}, {3.908931115690956*^9,
#    3.908931191427043*^9}, {3.9167988585590096`*^9, 3.9167988866007805`*^9},
#    3.9168325479983807`*^9, {3.9170051530546684`*^9, 3.9170051727469225`*^9}, {
#    3.917011903239862*^9, 3.917011910171091*^9}, {3.975783594742652*^9,
#    3.975783606781439*^9}},
#  CellLabel->"In[2]:=",ExpressionUUID->"0319fad8-da24-4500-af78-d8de4490f869"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-11"></a>
#
# <details>
# <summary>Original source cell 11; Output; source line 1385; group 9.2</summary>
#
# ```wolfram
# Cell[BoxData[
#  FractionBox[
#   RowBox[{
#    RowBox[{"b", " ",
#     RowBox[{"(",
#      RowBox[{
#       RowBox[{"2", " ", "d", " ",
#        RowBox[{"(",
#         RowBox[{"432", "+",
#          RowBox[{"z", " ",
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"-", "129"}], "+",
#             RowBox[{"17", " ", "z"}]}], ")"}]}], "+",
#          RowBox[{"12", " ", "b", " ",
#           RowBox[{"(",
#            RowBox[{"21", "+",
#             RowBox[{
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"-", "7"}], "+", "z"}], ")"}], " ", "z"}]}], ")"}]}]}],
#          ")"}]}], "+",
#       RowBox[{"3", " ", "c", " ",
#        RowBox[{"(",
#         RowBox[{"350", "+",
#          RowBox[{"z", " ",
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"-", "124"}], "+",
#             RowBox[{"19", " ", "z"}]}], ")"}]}], "+",
#          RowBox[{"14", " ", "b", " ",
#           RowBox[{"(",
#            RowBox[{"15", "+",
#             RowBox[{
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"-", "6"}], "+", "z"}], ")"}], " ", "z"}]}], ")"}]}]}],
#          ")"}]}]}], ")"}]}], "-",
#    RowBox[{"6", " ",
#     RowBox[{"(",
#      RowBox[{"1", "+", "b"}], ")"}], " ",
#     RowBox[{"(",
#      RowBox[{
#       RowBox[{"5", " ", "d", " ",
#        RowBox[{"(",
#         RowBox[{"28", "+",
#          RowBox[{
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"-", "8"}], "+", "z"}], ")"}], " ", "z"}]}], ")"}]}], "+",
#       RowBox[{"8", " ", "c", " ",
#        RowBox[{"(",
#         RowBox[{"21", "+",
#          RowBox[{
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"-", "7"}], "+", "z"}], ")"}], " ", "z"}]}], ")"}]}]}],
#      ")"}], " ",
#     RowBox[{"Log", "[",
#      RowBox[{"1", "+", "b"}], "]"}]}]}],
#   RowBox[{"5040", " ", "b"}]]], "Output",
#  CellChangeTimes->{3.917005177456105*^9, 3.9170119151118193`*^9,
#   3.917023497904213*^9, 3.975783686825877*^9},
#  CellLabel->"Out[2]=",ExpressionUUID->"dd4cfc2d-2677-46e4-8c49-b0bda3e7d784"]
# ```
#
# </details>
