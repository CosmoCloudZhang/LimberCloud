# %% [markdown]
# # SS: Coefficient B05
#
# Readable edition of the original Mathematica derivation. Scientific cells remain in source order. Normalized power uses $p=1-P_1/P_2$ in the reading edition; original spellings and complete source cells are preserved in the appendix. Cached Wolfram outputs are transcribed results, not a fresh execution.
#
# [Original Mathematica notebook](Coefficient_B05.nb) · [Conversion inventory and notation ledger](../README.md)
#
# The displayed dimensional integrals, definitions, normalized I/J integrals, inputs and outputs follow the author's original sequence. No runtime data or Mathematica installation is needed to read this notebook.

# %% [markdown]
# [Source cell 1](#source-01), `InlineFormula`.
#
# $$
# B^{i = n+1 < N, j = n+1 < N}_{\kappa \kappa, n}= \frac{9 \Omega_{\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \int_{\chi_{n}}^{\chi_{n + 1}} \mathrm{d} \chi  \left( \frac{\chi_{n + 2}-\chi_{n + 1}}{2}-\frac{\chi \chi_{n + 2}}{\chi_{n + 2}-\chi_{n + 1}}\ln{\frac{\chi_{n + 2}}{\chi_{n + 1}}}+\frac{\chi_{n + 1}^2-2\chi_{n}\chi_{n + 1}+\chi^2}{2\left( \chi_{n + 1}-\chi_{n}  \right)}+\frac{\chi \chi_{n}}{\chi_{n + 1}-\chi_{n}}\ln{\frac{\chi_{n + 1}}{\chi}} \right)^2 \left( \frac{\chi_{n + 1} - \chi}{\chi_{n + 1} - \chi_n} P_\ell^{n} + \frac{\chi - \chi_n}{\chi_{n + 1} - \chi_n} P_\ell^{n + 1} \right) \left(1 + \frac{\chi_{n + 1} - \chi}{\chi_{n + 1} - \chi_n} z_{n} + \frac{\chi - \chi_{n}}{\chi_{n + 1} - \chi_{n}} z_{n + 1} \right)^2
# $$

# %% [markdown]
# [Source cell 2](#source-02), `InlineFormula`.
#
# $$
# B^{i = 1, j = 1}_{\kappa \kappa, 0}= \frac{9 \Omega_{\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \int_{0}^{\chi_{1}} \mathrm{d} \chi  \left( \frac{\chi_{2}-\chi_{1}}{2}-\frac{\chi \chi_{2}}{\chi_{2}-\chi_{1}}\ln{\frac{\chi_{2}}{\chi_{1}}}+\frac{\chi_{1}^2+\chi^2}{2\chi_{1}} \right)^2 \left( \frac{\chi^3}{\chi_{1}^3}P_\ell^{1} \right)  \left(1 + \frac{\chi}{\chi_{1} } z_{1} \right)^2
# $$

# %% [markdown]
# [Source cell 3](#source-03), `InlineFormula`.
#
# $$
# t = \frac{\chi}{\chi_{n + 1}}
# $$
#
# $$
# p = \frac{P_\ell ^{n + 1}- P_\ell^{n}}{P_\ell^{n + 1}}
# $$
#
# $$
# z = \frac{z_{n + 1}- z_{n}}{1 + z_{n + 1}}
# $$
#
# $$
# a = \frac{\chi_{n + 1}- \chi_{n}}{\chi_{n + 1}}
# $$
#
# $$
# b = \frac{\chi_{n + 2}- \chi_{n + 1}}{\chi_{n + 1}}
# $$

# %% [markdown]
# [Source cell 4](#source-04), `InlineFormula`.
#
# $$
# B^{i = n+1 < N, j = n+1 < N}_{\kappa \kappa, n}= \frac{9 \Omega_{\mathrm{m}, 0}^2 H_0^4}{4 c^4} \chi^3_{n + 1} P_\ell^{n + 1} (1 + z_{n + 1})^2 I_5
# $$

# %% [markdown]
# [Source cell 5](#source-05), `InlineFormula`.
#
# $$
# B^{i = 1, j = 1}_{\kappa \kappa,0}= \frac{9 \Omega_{\mathrm{m}, 0}^2 H_0^4}{4 c^4} \chi^3_{1} P_\ell^{1} (1 + z_{1})^2 J_5
# $$

# %% [markdown]
# [Source cell 6](#source-06), `InlineFormula`.
#
# $$
# I_5 = \int_{1-a}^{1} \mathrm{d} t \:  \left( \frac{b}{2}-\frac{t \left( b+1\right)}{b} \ln{\left( b+1 \right)} + 1 - \frac{1-t^2}{2a}-\frac{t \left(  1-a \right) }{a} \ln{t}  \right)^2 \left( 1 - \frac{p}{a} (1 - t) \right) \left( 1 - \frac{z}{a} (1 - t) \right)^2
# $$

# %% [markdown]
# [Source cell 7](#source-07), `InlineFormula`.
#
# $$
# J_5 = \int_{0}^{1} \mathrm{d} t \:  \left( \frac{b}{2}-\frac{t \left( b+1\right)}{b} \ln{\left( b+1 \right)}+\frac{1+t^2}{2}  \right)^2 t^3 \left( 1 - z (1 - t) \right)^2
# $$

# %% [markdown]
# ### Symbolic input
#
# [Source cell 8](#source-08), `Input`.
#
# Corrected notation; Wolfram Language shown as text.
#
# ```wolfram
# I5= FullSimplify[Integrate[(((b)/(2)-(t (b+1))/(b) Log[b+1]+1-(1 - (t)^(2))/(2 a)-(t(1-a))/(a)Log[t]))^(2)(1-(p)/(a)(1-t))((1-(z)/(a)(1-t)))^(2),{t,1-a,1},Assumptions->Element[{a,b,p,z},Reals]&&{a,p,z}<1]]
# ```

# %% [markdown]
# ### Saved symbolic output
#
# [Source cell 9](#source-09), `Output`.
#
# Transcribed cached result, with the noted symbol renaming only.
#
# $$
# \frac{1}{5292000\,{a}^{5}\,{b}^{2}}(a\,{b}^{2}\,(245\,{a}^{2}\,(420\,p+a\,(-600+{a}^{4}\,(4030-2439\,p)-90\,(39+40\,b)\,p+5\,{a}^{2}\,(-220-60\,b\,(-2\,(-9+p)+9\,b\,(-2+p))+133\,p)+{a}^{3}\,(-2150+300\,b\,(30-17\,p)+404\,p)+20\,a\,(495+34\,p+90\,b\,(6+p))))+14\,a\,(-10920\,p-70\,{a}^{3}\,(-340+150\,b\,(-6+p)+163\,p)+{a}^{6}\,(-85365+60096\,p)+420\,a\,(35+3\,(53+50\,b)\,p)-70\,{a}^{2}\,(1755+232\,p+450\,b\,(4+p))+14\,{a}^{5}\,(1010-303\,p+75\,b\,(-170+117\,p))+7\,{a}^{4}\,(3325-952\,p+750\,b\,(4-p+6\,b\,(-3+2\,p))))\,z+({a}^{7}\,(420672-322375\,p)+59220\,p+35\,{a}^{3}\,(-3248+1260\,b\,(-5+p)+1371\,p)+{a}^{6}\,(-29694+4410\,b\,(195-148\,p)+11624\,p)-210\,a\,(364+3\,(481+420\,b)\,p)+14\,{a}^{4}\,(-5705+1941\,p+525\,b\,(-10+3\,p))+420\,{a}^{2}\,(1113+197\,p+105\,b\,(10+3\,p))-7\,{a}^{5}\,(6664-2441\,p+210\,b\,(25-9\,p+75\,b\,(-4+3\,p))))\,{z}^{2})+420\,(-210\,{(-1+a)}^{5}\,{b}^{2}\,(5\,{a}^{2}\,(p+a\,(-4+3\,p))-2\,a\,(2\,p+a\,(-5+6\,p+3\,a\,(-5+4\,p)))\,z+(-2\,a\,(1+3\,a+6\,{a}^{2})+p+a\,(3+2\,a\,(3+5\,a))\,p)\,{z}^{2})\,{\log [1-a]}^{2}+{(-1+a)}^{3}\,b\,\log [1-a]\,(b\,(35\,{a}^{2}\,(-10\,a\,(-1+a\,(2+17\,a+18\,b))+(-7+a\,(11+60\,b+a\,(59+117\,a+120\,b)))\,p)-14\,a\,(-5\,a\,(-7+a\,(11+60\,b+a\,(59+117\,a+120\,b)))+2\,(-13+a\,(17+75\,b+a\,(77+150\,b+3\,a\,(49+74\,a+75\,b))))\,p)\,z+(-14\,a\,(-13+a\,(17+75\,b+a\,(77+150\,b+3\,a\,(49+74\,a+75\,b))))+(-141+a\,(159+669\,a+1249\,{a}^{2}+1864\,{a}^{3}+2500\,{a}^{4}+630\,(1+a\,(2+a\,(3+4\,a)))\,b))\,p)\,{z}^{2})+420\,(-1+a)\,a\,(1+b)\,(5\,{a}^{2}\,(p+a\,(-4+3\,p))-2\,a\,(2\,p+a\,(-5+6\,p+3\,a\,(-5+4\,p)))\,z+(-2\,a\,(1+3\,a+6\,{a}^{2})+p+a\,(3+2\,a\,(3+5\,a))\,p)\,{z}^{2})\,\log [1+b])-{a}^{2}\,(1+b)\,\log [1+b]\,(b\,(-420\,p\,{z}^{2}+210\,a\,z\,(4\,z+p\,(8+z))+{a}^{6}\,(-5950+4095\,p+42\,(195-74\,z)\,z+4\,p\,z\,(-1554+625\,z))+70\,{a}^{2}\,(-6\,z\,(10+z)+p\,(-30+(-12+z)\,z))+35\,{a}^{3}\,(240-4\,(-15+z)\,z+p\,(30+(-8+z)\,z))+7\,{a}^{5}\,(-25\,(-64+35\,p+70\,z)+2\,z\,(p\,(594-224\,z)+297\,z)+30\,b\,(-30+20\,p+5\,(8-3\,z)\,z+6\,p\,z\,(-5+2\,z)))+7\,{a}^{4}\,(50\,(-12+p)-20\,(-5+p)\,z+(-10+3\,p)\,{z}^{2}-150\,b\,(-4\,(3+(-3+z)\,z)+p\,(6+z\,(-8+3\,z)))))+210\,{a}^{4}\,(1+b)\,(-20\,(3+(-3+a)\,a)+5\,(6+a\,(-8+3\,a))\,p+2\,(30+5\,a\,(-8+3\,a)-20\,p+6\,(5-2\,a)\,a\,p)\,z+(5\,(-4+3\,p)+2\,a\,(15-12\,p+a\,(-6+5\,p)))\,{z}^{2})\,\log [1+b])))
# $$

# %% [markdown]
# ### Symbolic input
#
# [Source cell 10](#source-10), `Input`.
#
# Corrected notation; Wolfram Language shown as text.
#
# ```wolfram
# J5= FullSimplify[Integrate[(((b)/(2)-(t (b+1))/(b) Log[b+1]+(1 + (t)^(2))/(2)))^(2)((t)^(3))((1-z(1-t)))^(2),{t,0,1},Assumptions->Element[{b,z},Reals]&&{z}<1]]
# ```

# %% [markdown]
# ### Saved symbolic output
#
# [Source cell 11](#source-11), `Output`.
#
# Transcribed cached result, with the noted symbol renaming only.
#
# $$
# \frac{{b}^{2}\,(1785+z\,(-562+79\,z)+42\,{b}^{2}\,(15+(-6+z)\,z)+6\,b\,(350+z\,(-124+19\,z)))-8\,b\,(1+b)\,(432+z\,(-129+17\,z)+12\,b\,(21+(-7+z)\,z))\,\log [1+b]+60\,{(1+b)}^{2}\,(28+(-8+z)\,z)\,{\log [1+b]}^{2}}{10080\,{b}^{2}}
# $$

# %% [markdown]
# ## Exact original content cells
#
# All source content cells follow in their original order, including original spellings, assumptions, saved outputs and cell metadata. Frontend-level metadata remains in the unchanged `.nb` file. Expand an entry to inspect its Wolfram box source.

# %% [markdown]
# <a id="source-01"></a>
#
# <details>
# <summary>Original source cell 1; InlineFormula; source line 21; group 1</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Integral]",
#          SubscriptBox["\[Chi]",
#           StyleBox["n", "TI"]],
#          SubscriptBox["\[Chi]",
#           RowBox[{
#             StyleBox["n", "TI"], "+", "1"}]]],
#         StyleBox["d", FontSlant -> "Plain"], "\[Chi]",
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{
#              FractionBox[
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "2"}]], "-",
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]]}], "2"], "-",
#              FractionBox[
#               SubscriptBox["\[Chi]\[Chi]",
#                RowBox[{
#                  StyleBox["n", "TI"], "+", "2"}]],
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "2"}]], "-",
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]]}]], "ln",
#              FractionBox[
#               SubscriptBox["\[Chi]",
#                RowBox[{
#                  StyleBox["n", "TI"], "+", "2"}]],
#               SubscriptBox["\[Chi]",
#                RowBox[{
#                  StyleBox["n", "TI"], "+", "1"}]]], "+",
#              FractionBox[
#               RowBox[{
#                 SubsuperscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}], "2"], "-", "2",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]],
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "+",
#                 SuperscriptBox["\[Chi]", "2"]}],
#               RowBox[{"2", "(",
#                 RowBox[{
#                   SubscriptBox["\[Chi]",
#                    RowBox[{
#                     StyleBox["n", "TI"], "+", "1"}]], "-",
#                   SubscriptBox["\[Chi]",
#                    StyleBox["n", "TI"]]}], ")"}]], "+",
#              FractionBox[
#               SubscriptBox["\[Chi]\[Chi]",
#                StyleBox["n", "TI"]],
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}]], "ln",
#              FractionBox[
#               SubscriptBox["\[Chi]",
#                RowBox[{
#                  StyleBox["n", "TI"], "+", "1"}]], "\[Chi]"]}], ")"}], "2"],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-", "\[Chi]"}],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}]],
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              StyleBox["n", "TI"]], "+",
#             FractionBox[
#              RowBox[{"\[Chi]", "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}]],
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}], ")"}],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              FractionBox[
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-", "\[Chi]"}],
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}]],
#              SubscriptBox[
#               StyleBox["z", "TI"],
#               StyleBox["n", "TI"]], "+",
#              FractionBox[
#               RowBox[{"\[Chi]", "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}],
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}]],
#              SubscriptBox[
#               StyleBox["z", "TI"],
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]]}], ")"}], "2"]}],
#       TraditionalForm], "errors" -> {}, "input" ->
#     "B^{i = n+1 < N, j = n+1 < N}_{\\kappa \\kappa, n}= \\frac{9 \
# \\Omega_{\\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \\int_{\\chi_{n}}^{\\chi_{n + 1}} \
# \\mathrm{d} \\chi  \\left( \\frac{\\chi_{n + 2}-\\chi_{n + \
# 1}}{2}-\\frac{\\chi \\chi_{n + 2}}{\\chi_{n + 2}-\\chi_{n + \
# 1}}\\ln{\\frac{\\chi_{n + 2}}{\\chi_{n + 1}}}+\\frac{\\chi_{n + \
# 1}^2-2\\chi_{n}\\chi_{n + 1}+\\chi^2}{2\\left( \\chi_{n + 1}-\\chi_{n}  \
# \\right)}+\\frac{\\chi \\chi_{n}}{\\chi_{n + \
# 1}-\\chi_{n}}\\ln{\\frac{\\chi_{n + 1}}{\\chi}} \\right)^2 \\left( \
# \\frac{\\chi_{n + 1} - \\chi}{\\chi_{n + 1} - \\chi_n} P_\\ell^{n} + \
# \\frac{\\chi - \\chi_n}{\\chi_{n + 1} - \\chi_n} P_\\ell^{n + 1} \\right) \
# \\left(1 + \\frac{\\chi_{n + 1} - \\chi}{\\chi_{n + 1} - \\chi_n} z_{n} + \
# \\frac{\\chi - \\chi_{n}}{\\chi_{n + 1} - \\chi_{n}} z_{n + 1} \\right)^2",
#     "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"e1060f81-6eef-42a2-8a6a-5a1f65ccf9e0"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.97578227428969*^9},ExpressionUUID->"8ead79e0-f5ce-41cb-96a5-27d91d066e49"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-02"></a>
#
# <details>
# <summary>Original source cell 2; InlineFormula; source line 194; group 2</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",", "0"}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]", "1", ",",
#            StyleBox["j", "TI"], "\[LongEqual]", "1"}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Integral]", "0",
#          SubscriptBox["\[Chi]", "1"]],
#         StyleBox["d", FontSlant -> "Plain"], "\[Chi]",
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{
#              FractionBox[
#               RowBox[{
#                 SubscriptBox["\[Chi]", "2"], "-",
#                 SubscriptBox["\[Chi]", "1"]}], "2"], "-",
#              FractionBox[
#               SubscriptBox["\[Chi]\[Chi]", "2"],
#               RowBox[{
#                 SubscriptBox["\[Chi]", "2"], "-",
#                 SubscriptBox["\[Chi]", "1"]}]], "ln",
#              FractionBox[
#               SubscriptBox["\[Chi]", "2"],
#               SubscriptBox["\[Chi]", "1"]], "+",
#              FractionBox[
#               RowBox[{
#                 SubsuperscriptBox["\[Chi]", "1", "2"], "+",
#                 SuperscriptBox["\[Chi]", "2"]}],
#               RowBox[{"2",
#                 SubscriptBox["\[Chi]", "1"]}]]}], ")"}], "2"],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              SuperscriptBox["\[Chi]", "3"],
#              SubsuperscriptBox["\[Chi]", "1", "3"]],
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]", "1"]}], ")"}],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              FractionBox["\[Chi]",
#               SubscriptBox["\[Chi]", "1"]],
#              SubscriptBox[
#               StyleBox["z", "TI"], "1"]}], ")"}], "2"]}], TraditionalForm],
#     "errors" -> {}, "input" ->
#     "B^{i = 1, j = 1}_{\\kappa \\kappa, 0}= \\frac{9 \\Omega_{\\mathrm{m}, \
# 0}^2 H_ 0^4}{4 c^4} \\int_{0}^{\\chi_{1}} \\mathrm{d} \\chi  \\left( \
# \\frac{\\chi_{2}-\\chi_{1}}{2}-\\frac{\\chi \
# \\chi_{2}}{\\chi_{2}-\\chi_{1}}\\ln{\\frac{\\chi_{2}}{\\chi_{1}}}+\\frac{\\\
# chi_{1}^2+\\chi^2}{2\\chi_{1}} \\right)^2 \\left( \
# \\frac{\\chi^3}{\\chi_{1}^3}P_\\ell^{1} \\right)  \\left(1 + \
# \\frac{\\chi}{\\chi_{1} } z_{1} \\right)^2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"1bb2591e-837e-4379-9925-091a4f4fe898"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.9757823044838867`*^9},ExpressionUUID->"15f55e58-900f-452c-a416-\
# acae23749683"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-03"></a>
#
# <details>
# <summary>Original source cell 3; InlineFormula; source line 267; group 3</summary>
#
# ```wolfram
# Cell[TextData[{
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["t", "TI"], "\[LongEqual]",
#          FractionBox["\[Chi]",
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" -> "t = \\frac{\\chi}{\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "4912d5c3-8324-4d69-b599-aa8184e5949f"],
#  ",  ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["p", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]], "-",
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              StyleBox["n", "TI"]]}],
#           SubsuperscriptBox[
#            StyleBox["P", "TI"], "\[ScriptL]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "p = \\frac{P_\\ell ^{n + 1}- P_\\ell^{n}}{P_\\ell^{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "2eee0d46-505d-4d0b-a58e-a80e9d4b755e"],
#  ", ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["z", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox[
#              StyleBox["z", "TI"],
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]], "-",
#             SubscriptBox[
#              StyleBox["z", "TI"],
#              StyleBox["n", "TI"]]}],
#           RowBox[{"1", "+",
#             SubscriptBox[
#              StyleBox["z", "TI"],
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}]]}], TraditionalForm],
#      "errors" -> {}, "input" -> "z = \\frac{z_{n + 1}- z_{n}}{1 + z_{n + 1}}",
#       "state" -> "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "be8b5f05-d2fa-477e-8c94-d8b2004eff86"],
#  ", ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["a", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]], "-",
#             SubscriptBox["\[Chi]",
#              StyleBox["n", "TI"]]}],
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "a = \\frac{\\chi_{n + 1}- \\chi_{n}}{\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "c6720938-c756-4d3e-8afb-dc3f4a2fd607"],
#  ",",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["b", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "2"}]], "-",
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}],
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "b = \\frac{\\chi_{n + 2}- \\chi_{n + 1}}{\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "ce760377-6b1a-44ec-9037-03984fbdc85d"]
# }], "InlineFormula",
#  CellChangeTimes->{{3.887196302307176*^9, 3.887196331440764*^9}, {
#    3.887196362536772*^9, 3.887196382134186*^9}, {3.9084206984864616`*^9,
#    3.9084207040669937`*^9}, 3.9084340401865296`*^9, 3.9084351731002855`*^9,
#    3.9084355812628045`*^9, {3.908930179531493*^9,
#    3.9089301824177485`*^9}},ExpressionUUID->"7b6246ea-d307-486a-90da-\
# c05c2c9b0953"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-04"></a>
#
# <details>
# <summary>Original source cell 4; InlineFormula; source line 380; group 4</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Chi]",
#          RowBox[{
#            StyleBox["n", "TI"], "+", "1"}], "3"],
#         SubsuperscriptBox[
#          StyleBox["P", "TI"], "\[ScriptL]",
#          RowBox[{
#            StyleBox["n", "TI"], "+", "1"}]],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              SubscriptBox[
#               StyleBox["z", "TI"],
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]]}], ")"}], "2"],
#         SubscriptBox[
#          StyleBox["I", "TI"], "5"]}], TraditionalForm], "errors" -> {},
#     "input" ->
#     "B^{i = n+1 < N, j = n+1 < N}_{\\kappa \\kappa, n}= \\frac{9 \
# \\Omega_{\\mathrm{m}, 0}^2 H_0^4}{4 c^4} \\chi^3_{n + 1} P_\\ell^{n + 1} (1 + \
# z_{n + 1})^2 I_5", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"042353f9-a993-4e9b-847c-3ce95bebc683"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196401920412*^9, {3.9084337680750885`*^9,
#    3.908433770987523*^9}},ExpressionUUID->"21cd44dd-49c8-44f7-a1b3-\
# e5707dd0452b"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-05"></a>
#
# <details>
# <summary>Original source cell 5; InlineFormula; source line 433; group 5</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",", "0"}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]", "1", ",",
#            StyleBox["j", "TI"], "\[LongEqual]", "1"}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Chi]", "1", "3"],
#         SubsuperscriptBox[
#          StyleBox["P", "TI"], "\[ScriptL]", "1"],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              SubscriptBox[
#               StyleBox["z", "TI"], "1"]}], ")"}], "2"],
#         SubscriptBox[
#          StyleBox["J", "TI"], "5"]}], TraditionalForm], "errors" -> {},
#     "input" ->
#     "B^{i = 1, j = 1}_{\\kappa \\kappa,0}= \\frac{9 \\Omega_{\\mathrm{m}, \
# 0}^2 H_0^4}{4 c^4} \\chi^3_{1} P_\\ell^{1} (1 + z_{1})^2 J_5", "state" ->
#     "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"1b8f012e-6b17-4e84-af7e-8ff86d17e7e3"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196401920412*^9, {3.9084337680750885`*^9,
#    3.908433770987523*^9}},ExpressionUUID->"43bb4ff2-9386-4ac2-9c82-\
# 602c6679b75d"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-06"></a>
#
# <details>
# <summary>Original source cell 6; InlineFormula; source line 475; group 6</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubscriptBox[
#          StyleBox["I", "TI"], "5"], "\[LongEqual]",
#         SubsuperscriptBox["\[Integral]",
#          RowBox[{"1", "-",
#            StyleBox["a", "TI"]}], "1"],
#         StyleBox["d", FontSlant -> "Plain"],
#         StyleBox["t", "TI"], " ",
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{
#              FractionBox[
#               StyleBox["b", "TI"], "2"], "-",
#              FractionBox[
#               RowBox[{
#                 StyleBox["t", "TI"], "(",
#                 RowBox[{
#                   StyleBox["b", "TI"], "+", "1"}], ")"}],
#               StyleBox["b", "TI"]], "ln",
#              RowBox[{"(",
#                RowBox[{
#                  StyleBox["b", "TI"], "+", "1"}], ")"}], "+", "1", "-",
#              FractionBox[
#               RowBox[{"1", "-",
#                 SuperscriptBox[
#                  StyleBox["t", "TI"], "2"]}],
#               RowBox[{"2",
#                 StyleBox["a", "TI"]}]], "-",
#              FractionBox[
#               RowBox[{
#                 StyleBox["t", "TI"], "(",
#                 RowBox[{"1", "-",
#                   StyleBox["a", "TI"]}], ")"}],
#               StyleBox["a", "TI"]], "ln",
#              StyleBox["t", "TI"]}], ")"}], "2"],
#         RowBox[{"(",
#           RowBox[{"1", "-",
#             FractionBox[
#              StyleBox["p", "TI"],
#              StyleBox["a", "TI"]],
#             RowBox[{"(",
#               RowBox[{"1", "-",
#                 StyleBox["t", "TI"]}], ")"}]}], ")"}],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "-",
#              FractionBox[
#               StyleBox["z", "TI"],
#               StyleBox["a", "TI"]],
#              RowBox[{"(",
#                RowBox[{"1", "-",
#                  StyleBox["t", "TI"]}], ")"}]}], ")"}], "2"]}],
#       TraditionalForm], "errors" -> {}, "input" ->
#     "I_5 = \\int_{1-a}^{1} \\mathrm{d} t \\:  \\left( \\frac{b}{2}-\\frac{t \
# \\left( b+1\\right)}{b} \\ln{\\left( b+1 \\right)} + 1 - \
# \\frac{1-t^2}{2a}-\\frac{t \\left(  1-a \\right) }{a} \\ln{t}  \\right)^2 \
# \\left( 1 - \\frac{p}{a} (1 - t) \\right) \\left( 1 - \\frac{z}{a} (1 - t) \
# \\right)^2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"f8d8d33b-26e6-44a7-ab4c-a2f5f26c6a82"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196539368146*^9},ExpressionUUID->"2e461cf4-f0f3-4eef-ba1c-\
# 97aa73b03444"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-07"></a>
#
# <details>
# <summary>Original source cell 7; InlineFormula; source line 543; group 7</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubscriptBox[
#          StyleBox["J", "TI"], "5"], "\[LongEqual]",
#         SubsuperscriptBox["\[Integral]", "0", "1"],
#         StyleBox["d", FontSlant -> "Plain"],
#         StyleBox["t", "TI"], " ",
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{
#              FractionBox[
#               StyleBox["b", "TI"], "2"], "-",
#              FractionBox[
#               RowBox[{
#                 StyleBox["t", "TI"], "(",
#                 RowBox[{
#                   StyleBox["b", "TI"], "+", "1"}], ")"}],
#               StyleBox["b", "TI"]], "ln",
#              RowBox[{"(",
#                RowBox[{
#                  StyleBox["b", "TI"], "+", "1"}], ")"}], "+",
#              FractionBox[
#               RowBox[{"1", "+",
#                 SuperscriptBox[
#                  StyleBox["t", "TI"], "2"]}], "2"]}], ")"}], "2"],
#         SuperscriptBox[
#          StyleBox["t", "TI"], "3"],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "-",
#              StyleBox["z", "TI"],
#              RowBox[{"(",
#                RowBox[{"1", "-",
#                  StyleBox["t", "TI"]}], ")"}]}], ")"}], "2"]}],
#       TraditionalForm], "errors" -> {}, "input" ->
#     "J_5 = \\int_{0}^{1} \\mathrm{d} t \\:  \\left( \\frac{b}{2}-\\frac{t \
# \\left( b+1\\right)}{b} \\ln{\\left( b+1 \\right)}+\\frac{1+t^2}{2}  \
# \\right)^2 t^3 \\left( 1 - z (1 - t) \\right)^2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"6d2222c6-d005-43bd-b583-f5fac105b0b5"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196539368146*^9},ExpressionUUID->"e00658b1-2375-432b-b4df-\
# 124e02271ca4"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-08"></a>
#
# <details>
# <summary>Original source cell 8; Input; source line 592; group 8.1</summary>
#
# ```wolfram
# Cell[BoxData[
#  RowBox[{"I5", "=", " ",
#   RowBox[{"FullSimplify", "[",
#    RowBox[{"Integrate", "[",
#     RowBox[{
#      RowBox[{
#       SuperscriptBox[
#        RowBox[{"(",
#         RowBox[{
#          FractionBox["b", "2"], "-",
#          RowBox[{
#           FractionBox[
#            RowBox[{"t", " ",
#             RowBox[{"(",
#              RowBox[{"b", "+", "1"}], ")"}]}], "b"], " ",
#           RowBox[{"Log", "[",
#            RowBox[{"b", "+", "1"}], "]"}]}], "+", "1", "-",
#          FractionBox[
#           RowBox[{"1", " ", "-", " ",
#            SuperscriptBox["t", "2"]}],
#           RowBox[{"2", " ", "a"}]], "-",
#          RowBox[{
#           FractionBox[
#            RowBox[{"t",
#             RowBox[{"(",
#              RowBox[{"1", "-", "a"}], ")"}]}], "a"],
#           RowBox[{"Log", "[", "t", "]"}]}]}], ")"}], "2"],
#       RowBox[{"(",
#        RowBox[{"1", "-",
#         RowBox[{
#          FractionBox["p", "a"],
#          RowBox[{"(",
#           RowBox[{"1", "-", "t"}], ")"}]}]}], ")"}],
#       SuperscriptBox[
#        RowBox[{"(",
#         RowBox[{"1", "-",
#          RowBox[{
#           FractionBox["z", "a"],
#           RowBox[{"(",
#            RowBox[{"1", "-", "t"}], ")"}]}]}], ")"}], "2"]}], ",",
#      RowBox[{"{",
#       RowBox[{"t", ",",
#        RowBox[{"1", "-", "a"}], ",", "1"}], "}"}], ",",
#      RowBox[{"Assumptions", "->",
#       RowBox[{
#        RowBox[{"Element", "[",
#         RowBox[{
#          RowBox[{"{",
#           RowBox[{"a", ",", "b", ",", "p", ",", "z"}], "}"}], ",", "Reals"}],
#         "]"}], "&&",
#        RowBox[{
#         RowBox[{"{",
#          RowBox[{"a", ",", "p", ",", "z"}], "}"}], "<", "1"}]}]}]}], "]"}],
#    "]"}]}]], "Input",
#  CellChangeTimes->{{3.8871966515420856`*^9, 3.887196657849538*^9}, {
#    3.887197019461763*^9, 3.8871970202578783`*^9}, 3.887197391169403*^9,
#    3.8876346041182613`*^9, {3.8879047776300783`*^9, 3.887904807663855*^9}, {
#    3.887904924599154*^9, 3.887904942996567*^9}, 3.888148387380184*^9, {
#    3.908436037243232*^9, 3.9084362203498116`*^9}, {3.9084386916235085`*^9,
#    3.9084387068005824`*^9}, {3.90893016363597*^9, 3.908930164383273*^9}, {
#    3.908930685235114*^9, 3.908930715874014*^9}, {3.916798285178237*^9,
#    3.916798285349015*^9}, {3.975782882249152*^9, 3.975782907118052*^9}},
#  CellLabel->"In[1]:=",ExpressionUUID->"43640b55-9bdb-44d4-99fa-5150f7081833"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-09"></a>
#
# <details>
# <summary>Original source cell 9; Output; source line 656; group 8.2</summary>
#
# ```wolfram
# Cell[BoxData[
#  RowBox[{
#   FractionBox["1",
#    RowBox[{"5292000", " ",
#     SuperscriptBox["a", "5"], " ",
#     SuperscriptBox["b", "2"]}]],
#   RowBox[{"(",
#    RowBox[{
#     RowBox[{"a", " ",
#      SuperscriptBox["b", "2"], " ",
#      RowBox[{"(",
#       RowBox[{
#        RowBox[{"245", " ",
#         SuperscriptBox["a", "2"], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"420", " ", "p"}], "+",
#           RowBox[{"a", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"-", "600"}], "+",
#              RowBox[{
#               SuperscriptBox["a", "4"], " ",
#               RowBox[{"(",
#                RowBox[{"4030", "-",
#                 RowBox[{"2439", " ", "p"}]}], ")"}]}], "-",
#              RowBox[{"90", " ",
#               RowBox[{"(",
#                RowBox[{"39", "+",
#                 RowBox[{"40", " ", "b"}]}], ")"}], " ", "p"}], "+",
#              RowBox[{"5", " ",
#               SuperscriptBox["a", "2"], " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "220"}], "-",
#                 RowBox[{"60", " ", "b", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{
#                     RowBox[{"-", "2"}], " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "9"}], "+", "p"}], ")"}]}], "+",
#                    RowBox[{"9", " ", "b", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "2"}], "+", "p"}], ")"}]}]}], ")"}]}], "+",
#                 RowBox[{"133", " ", "p"}]}], ")"}]}], "+",
#              RowBox[{
#               SuperscriptBox["a", "3"], " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "2150"}], "+",
#                 RowBox[{"300", " ", "b", " ",
#                  RowBox[{"(",
#                   RowBox[{"30", "-",
#                    RowBox[{"17", " ", "p"}]}], ")"}]}], "+",
#                 RowBox[{"404", " ", "p"}]}], ")"}]}], "+",
#              RowBox[{"20", " ", "a", " ",
#               RowBox[{"(",
#                RowBox[{"495", "+",
#                 RowBox[{"34", " ", "p"}], "+",
#                 RowBox[{"90", " ", "b", " ",
#                  RowBox[{"(",
#                   RowBox[{"6", "+", "p"}], ")"}]}]}], ")"}]}]}], ")"}]}]}],
#          ")"}]}], "+",
#        RowBox[{"14", " ", "a", " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{
#            RowBox[{"-", "10920"}], " ", "p"}], "-",
#           RowBox[{"70", " ",
#            SuperscriptBox["a", "3"], " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"-", "340"}], "+",
#              RowBox[{"150", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "6"}], "+", "p"}], ")"}]}], "+",
#              RowBox[{"163", " ", "p"}]}], ")"}]}], "+",
#           RowBox[{
#            SuperscriptBox["a", "6"], " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"-", "85365"}], "+",
#              RowBox[{"60096", " ", "p"}]}], ")"}]}], "+",
#           RowBox[{"420", " ", "a", " ",
#            RowBox[{"(",
#             RowBox[{"35", "+",
#              RowBox[{"3", " ",
#               RowBox[{"(",
#                RowBox[{"53", "+",
#                 RowBox[{"50", " ", "b"}]}], ")"}], " ", "p"}]}], ")"}]}], "-",
#           RowBox[{"70", " ",
#            SuperscriptBox["a", "2"], " ",
#            RowBox[{"(",
#             RowBox[{"1755", "+",
#              RowBox[{"232", " ", "p"}], "+",
#              RowBox[{"450", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{"4", "+", "p"}], ")"}]}]}], ")"}]}], "+",
#           RowBox[{"14", " ",
#            SuperscriptBox["a", "5"], " ",
#            RowBox[{"(",
#             RowBox[{"1010", "-",
#              RowBox[{"303", " ", "p"}], "+",
#              RowBox[{"75", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "170"}], "+",
#                 RowBox[{"117", " ", "p"}]}], ")"}]}]}], ")"}]}], "+",
#           RowBox[{"7", " ",
#            SuperscriptBox["a", "4"], " ",
#            RowBox[{"(",
#             RowBox[{"3325", "-",
#              RowBox[{"952", " ", "p"}], "+",
#              RowBox[{"750", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{"4", "-", "p", "+",
#                 RowBox[{"6", " ", "b", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "3"}], "+",
#                    RowBox[{"2", " ", "p"}]}], ")"}]}]}], ")"}]}]}], ")"}]}]}],
#           ")"}], " ", "z"}], "+",
#        RowBox[{
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{
#            SuperscriptBox["a", "7"], " ",
#            RowBox[{"(",
#             RowBox[{"420672", "-",
#              RowBox[{"322375", " ", "p"}]}], ")"}]}], "+",
#           RowBox[{"59220", " ", "p"}], "+",
#           RowBox[{"35", " ",
#            SuperscriptBox["a", "3"], " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"-", "3248"}], "+",
#              RowBox[{"1260", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "5"}], "+", "p"}], ")"}]}], "+",
#              RowBox[{"1371", " ", "p"}]}], ")"}]}], "+",
#           RowBox[{
#            SuperscriptBox["a", "6"], " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"-", "29694"}], "+",
#              RowBox[{"4410", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{"195", "-",
#                 RowBox[{"148", " ", "p"}]}], ")"}]}], "+",
#              RowBox[{"11624", " ", "p"}]}], ")"}]}], "-",
#           RowBox[{"210", " ", "a", " ",
#            RowBox[{"(",
#             RowBox[{"364", "+",
#              RowBox[{"3", " ",
#               RowBox[{"(",
#                RowBox[{"481", "+",
#                 RowBox[{"420", " ", "b"}]}], ")"}], " ", "p"}]}], ")"}]}],
#           "+",
#           RowBox[{"14", " ",
#            SuperscriptBox["a", "4"], " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"-", "5705"}], "+",
#              RowBox[{"1941", " ", "p"}], "+",
#              RowBox[{"525", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "10"}], "+",
#                 RowBox[{"3", " ", "p"}]}], ")"}]}]}], ")"}]}], "+",
#           RowBox[{"420", " ",
#            SuperscriptBox["a", "2"], " ",
#            RowBox[{"(",
#             RowBox[{"1113", "+",
#              RowBox[{"197", " ", "p"}], "+",
#              RowBox[{"105", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{"10", "+",
#                 RowBox[{"3", " ", "p"}]}], ")"}]}]}], ")"}]}], "-",
#           RowBox[{"7", " ",
#            SuperscriptBox["a", "5"], " ",
#            RowBox[{"(",
#             RowBox[{"6664", "-",
#              RowBox[{"2441", " ", "p"}], "+",
#              RowBox[{"210", " ", "b", " ",
#               RowBox[{"(",
#                RowBox[{"25", "-",
#                 RowBox[{"9", " ", "p"}], "+",
#                 RowBox[{"75", " ", "b", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "4"}], "+",
#                    RowBox[{"3", " ", "p"}]}], ")"}]}]}], ")"}]}]}], ")"}]}]}],
#           ")"}], " ",
#         SuperscriptBox["z", "2"]}]}], ")"}]}], "+",
#     RowBox[{"420", " ",
#      RowBox[{"(",
#       RowBox[{
#        RowBox[{
#         RowBox[{"-", "210"}], " ",
#         SuperscriptBox[
#          RowBox[{"(",
#           RowBox[{
#            RowBox[{"-", "1"}], "+", "a"}], ")"}], "5"], " ",
#         SuperscriptBox["b", "2"], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"5", " ",
#            SuperscriptBox["a", "2"], " ",
#            RowBox[{"(",
#             RowBox[{"p", "+",
#              RowBox[{"a", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "4"}], "+",
#                 RowBox[{"3", " ", "p"}]}], ")"}]}]}], ")"}]}], "-",
#           RowBox[{"2", " ", "a", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"2", " ", "p"}], "+",
#              RowBox[{"a", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "5"}], "+",
#                 RowBox[{"6", " ", "p"}], "+",
#                 RowBox[{"3", " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "5"}], "+",
#                    RowBox[{"4", " ", "p"}]}], ")"}]}]}], ")"}]}]}], ")"}],
#            " ", "z"}], "+",
#           RowBox[{
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{
#               RowBox[{"-", "2"}], " ", "a", " ",
#               RowBox[{"(",
#                RowBox[{"1", "+",
#                 RowBox[{"3", " ", "a"}], "+",
#                 RowBox[{"6", " ",
#                  SuperscriptBox["a", "2"]}]}], ")"}]}], "+", "p", "+",
#              RowBox[{"a", " ",
#               RowBox[{"(",
#                RowBox[{"3", "+",
#                 RowBox[{"2", " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{"3", "+",
#                    RowBox[{"5", " ", "a"}]}], ")"}]}]}], ")"}], " ", "p"}]}],
#             ")"}], " ",
#            SuperscriptBox["z", "2"]}]}], ")"}], " ",
#         SuperscriptBox[
#          RowBox[{"Log", "[",
#           RowBox[{"1", "-", "a"}], "]"}], "2"]}], "+",
#        RowBox[{
#         SuperscriptBox[
#          RowBox[{"(",
#           RowBox[{
#            RowBox[{"-", "1"}], "+", "a"}], ")"}], "3"], " ", "b", " ",
#         RowBox[{"Log", "[",
#          RowBox[{"1", "-", "a"}], "]"}], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"b", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"35", " ",
#               SuperscriptBox["a", "2"], " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"-", "10"}], " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "1"}], "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"2", "+",
#                     RowBox[{"17", " ", "a"}], "+",
#                     RowBox[{"18", " ", "b"}]}], ")"}]}]}], ")"}]}], "+",
#                 RowBox[{
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "7"}], "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"11", "+",
#                     RowBox[{"60", " ", "b"}], "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"59", "+",
#                     RowBox[{"117", " ", "a"}], "+",
#                     RowBox[{"120", " ", "b"}]}], ")"}]}]}], ")"}]}]}], ")"}],
#                  " ", "p"}]}], ")"}]}], "-",
#              RowBox[{"14", " ", "a", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"-", "5"}], " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "7"}], "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"11", "+",
#                     RowBox[{"60", " ", "b"}], "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"59", "+",
#                     RowBox[{"117", " ", "a"}], "+",
#                     RowBox[{"120", " ", "b"}]}], ")"}]}]}], ")"}]}]}],
#                   ")"}]}], "+",
#                 RowBox[{"2", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "13"}], "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"17", "+",
#                     RowBox[{"75", " ", "b"}], "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"77", "+",
#                     RowBox[{"150", " ", "b"}], "+",
#                     RowBox[{"3", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{"49", "+",
#                     RowBox[{"74", " ", "a"}], "+",
#                     RowBox[{"75", " ", "b"}]}], ")"}]}]}], ")"}]}]}],
#                     ")"}]}]}], ")"}], " ", "p"}]}], ")"}], " ", "z"}], "+",
#              RowBox[{
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"-", "14"}], " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "13"}], "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"17", "+",
#                     RowBox[{"75", " ", "b"}], "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"77", "+",
#                     RowBox[{"150", " ", "b"}], "+",
#                     RowBox[{"3", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{"49", "+",
#                     RowBox[{"74", " ", "a"}], "+",
#                     RowBox[{"75", " ", "b"}]}], ")"}]}]}], ")"}]}]}],
#                     ")"}]}]}], ")"}]}], "+",
#                 RowBox[{
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "141"}], "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"159", "+",
#                     RowBox[{"669", " ", "a"}], "+",
#                     RowBox[{"1249", " ",
#                     SuperscriptBox["a", "2"]}], "+",
#                     RowBox[{"1864", " ",
#                     SuperscriptBox["a", "3"]}], "+",
#                     RowBox[{"2500", " ",
#                     SuperscriptBox["a", "4"]}], "+",
#                     RowBox[{"630", " ",
#                     RowBox[{"(",
#                     RowBox[{"1", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"2", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"3", "+",
#                     RowBox[{"4", " ", "a"}]}], ")"}]}]}], ")"}]}]}], ")"}],
#                     " ", "b"}]}], ")"}]}]}], ")"}], " ", "p"}]}], ")"}], " ",
#               SuperscriptBox["z", "2"]}]}], ")"}]}], "+",
#           RowBox[{"420", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"-", "1"}], "+", "a"}], ")"}], " ", "a", " ",
#            RowBox[{"(",
#             RowBox[{"1", "+", "b"}], ")"}], " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{"5", " ",
#               SuperscriptBox["a", "2"], " ",
#               RowBox[{"(",
#                RowBox[{"p", "+",
#                 RowBox[{"a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "4"}], "+",
#                    RowBox[{"3", " ", "p"}]}], ")"}]}]}], ")"}]}], "-",
#              RowBox[{"2", " ", "a", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"2", " ", "p"}], "+",
#                 RowBox[{"a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "5"}], "+",
#                    RowBox[{"6", " ", "p"}], "+",
#                    RowBox[{"3", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "5"}], "+",
#                     RowBox[{"4", " ", "p"}]}], ")"}]}]}], ")"}]}]}], ")"}],
#               " ", "z"}], "+",
#              RowBox[{
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"-", "2"}], " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{"1", "+",
#                    RowBox[{"3", " ", "a"}], "+",
#                    RowBox[{"6", " ",
#                     SuperscriptBox["a", "2"]}]}], ")"}]}], "+", "p", "+",
#                 RowBox[{"a", " ",
#                  RowBox[{"(",
#                   RowBox[{"3", "+",
#                    RowBox[{"2", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{"3", "+",
#                     RowBox[{"5", " ", "a"}]}], ")"}]}]}], ")"}], " ", "p"}]}],
#                 ")"}], " ",
#               SuperscriptBox["z", "2"]}]}], ")"}], " ",
#            RowBox[{"Log", "[",
#             RowBox[{"1", "+", "b"}], "]"}]}]}], ")"}]}], "-",
#        RowBox[{
#         SuperscriptBox["a", "2"], " ",
#         RowBox[{"(",
#          RowBox[{"1", "+", "b"}], ")"}], " ",
#         RowBox[{"Log", "[",
#          RowBox[{"1", "+", "b"}], "]"}], " ",
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"b", " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{
#               RowBox[{"-", "420"}], " ", "p", " ",
#               SuperscriptBox["z", "2"]}], "+",
#              RowBox[{"210", " ", "a", " ", "z", " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"4", " ", "z"}], "+",
#                 RowBox[{"p", " ",
#                  RowBox[{"(",
#                   RowBox[{"8", "+", "z"}], ")"}]}]}], ")"}]}], "+",
#              RowBox[{
#               SuperscriptBox["a", "6"], " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"-", "5950"}], "+",
#                 RowBox[{"4095", " ", "p"}], "+",
#                 RowBox[{"42", " ",
#                  RowBox[{"(",
#                   RowBox[{"195", "-",
#                    RowBox[{"74", " ", "z"}]}], ")"}], " ", "z"}], "+",
#                 RowBox[{"4", " ", "p", " ", "z", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "1554"}], "+",
#                    RowBox[{"625", " ", "z"}]}], ")"}]}]}], ")"}]}], "+",
#              RowBox[{"70", " ",
#               SuperscriptBox["a", "2"], " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"-", "6"}], " ", "z", " ",
#                  RowBox[{"(",
#                   RowBox[{"10", "+", "z"}], ")"}]}], "+",
#                 RowBox[{"p", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "30"}], "+",
#                    RowBox[{
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "12"}], "+", "z"}], ")"}], " ", "z"}]}],
#                   ")"}]}]}], ")"}]}], "+",
#              RowBox[{"35", " ",
#               SuperscriptBox["a", "3"], " ",
#               RowBox[{"(",
#                RowBox[{"240", "-",
#                 RowBox[{"4", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "15"}], "+", "z"}], ")"}], " ", "z"}], "+",
#                 RowBox[{"p", " ",
#                  RowBox[{"(",
#                   RowBox[{"30", "+",
#                    RowBox[{
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "8"}], "+", "z"}], ")"}], " ", "z"}]}],
#                   ")"}]}]}], ")"}]}], "+",
#              RowBox[{"7", " ",
#               SuperscriptBox["a", "5"], " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{
#                  RowBox[{"-", "25"}], " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "64"}], "+",
#                    RowBox[{"35", " ", "p"}], "+",
#                    RowBox[{"70", " ", "z"}]}], ")"}]}], "+",
#                 RowBox[{"2", " ", "z", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"p", " ",
#                     RowBox[{"(",
#                     RowBox[{"594", "-",
#                     RowBox[{"224", " ", "z"}]}], ")"}]}], "+",
#                    RowBox[{"297", " ", "z"}]}], ")"}]}], "+",
#                 RowBox[{"30", " ", "b", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "30"}], "+",
#                    RowBox[{"20", " ", "p"}], "+",
#                    RowBox[{"5", " ",
#                     RowBox[{"(",
#                     RowBox[{"8", "-",
#                     RowBox[{"3", " ", "z"}]}], ")"}], " ", "z"}], "+",
#                    RowBox[{"6", " ", "p", " ", "z", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "5"}], "+",
#                     RowBox[{"2", " ", "z"}]}], ")"}]}]}], ")"}]}]}], ")"}]}],
#              "+",
#              RowBox[{"7", " ",
#               SuperscriptBox["a", "4"], " ",
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"50", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "12"}], "+", "p"}], ")"}]}], "-",
#                 RowBox[{"20", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "5"}], "+", "p"}], ")"}], " ", "z"}], "+",
#                 RowBox[{
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "10"}], "+",
#                    RowBox[{"3", " ", "p"}]}], ")"}], " ",
#                  SuperscriptBox["z", "2"]}], "-",
#                 RowBox[{"150", " ", "b", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{
#                     RowBox[{"-", "4"}], " ",
#                     RowBox[{"(",
#                     RowBox[{"3", "+",
#                     RowBox[{
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "3"}], "+", "z"}], ")"}], " ", "z"}]}],
#                     ")"}]}], "+",
#                    RowBox[{"p", " ",
#                     RowBox[{"(",
#                     RowBox[{"6", "+",
#                     RowBox[{"z", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "8"}], "+",
#                     RowBox[{"3", " ", "z"}]}], ")"}]}]}], ")"}]}]}],
#                   ")"}]}]}], ")"}]}]}], ")"}]}], "+",
#           RowBox[{"210", " ",
#            SuperscriptBox["a", "4"], " ",
#            RowBox[{"(",
#             RowBox[{"1", "+", "b"}], ")"}], " ",
#            RowBox[{"(",
#             RowBox[{
#              RowBox[{
#               RowBox[{"-", "20"}], " ",
#               RowBox[{"(",
#                RowBox[{"3", "+",
#                 RowBox[{
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "3"}], "+", "a"}], ")"}], " ", "a"}]}],
#                ")"}]}], "+",
#              RowBox[{"5", " ",
#               RowBox[{"(",
#                RowBox[{"6", "+",
#                 RowBox[{"a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "8"}], "+",
#                    RowBox[{"3", " ", "a"}]}], ")"}]}]}], ")"}], " ", "p"}],
#              "+",
#              RowBox[{"2", " ",
#               RowBox[{"(",
#                RowBox[{"30", "+",
#                 RowBox[{"5", " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "8"}], "+",
#                    RowBox[{"3", " ", "a"}]}], ")"}]}], "-",
#                 RowBox[{"20", " ", "p"}], "+",
#                 RowBox[{"6", " ",
#                  RowBox[{"(",
#                   RowBox[{"5", "-",
#                    RowBox[{"2", " ", "a"}]}], ")"}], " ", "a", " ", "p"}]}],
#                ")"}], " ", "z"}], "+",
#              RowBox[{
#               RowBox[{"(",
#                RowBox[{
#                 RowBox[{"5", " ",
#                  RowBox[{"(",
#                   RowBox[{
#                    RowBox[{"-", "4"}], "+",
#                    RowBox[{"3", " ", "p"}]}], ")"}]}], "+",
#                 RowBox[{"2", " ", "a", " ",
#                  RowBox[{"(",
#                   RowBox[{"15", "-",
#                    RowBox[{"12", " ", "p"}], "+",
#                    RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "6"}], "+",
#                     RowBox[{"5", " ", "p"}]}], ")"}]}]}], ")"}]}]}], ")"}],
#               " ",
#               SuperscriptBox["z", "2"]}]}], ")"}], " ",
#            RowBox[{"Log", "[",
#             RowBox[{"1", "+", "b"}], "]"}]}]}], ")"}]}]}], ")"}]}]}],
#    ")"}]}]], "Output",
#  CellChangeTimes->{{3.908421068111334*^9, 3.9084210920073547`*^9},
#    3.908436269683008*^9, 3.908438781589342*^9, 3.9089309309437437`*^9,
#    3.9095606737283983`*^9, 3.916798424733305*^9, 3.9168102597549114`*^9,
#    3.9168181801189394`*^9, 3.9168323895550833`*^9, 3.9168352445776196`*^9,
#    3.9170232331884775`*^9, 3.975783040489607*^9},
#  CellLabel->"Out[1]=",ExpressionUUID->"fa5446e7-7633-4565-8e7b-645553fab254"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-10"></a>
#
# <details>
# <summary>Original source cell 10; Input; source line 1302; group 9.1</summary>
#
# ```wolfram
# Cell[BoxData[
#  RowBox[{"J5", "=", " ",
#   RowBox[{"FullSimplify", "[",
#    RowBox[{"Integrate", "[",
#     RowBox[{
#      RowBox[{
#       SuperscriptBox[
#        RowBox[{"(",
#         RowBox[{
#          FractionBox["b", "2"], "-",
#          RowBox[{
#           FractionBox[
#            RowBox[{"t", " ",
#             RowBox[{"(",
#              RowBox[{"b", "+", "1"}], ")"}]}], "b"], " ",
#           RowBox[{"Log", "[",
#            RowBox[{"b", "+", "1"}], "]"}]}], "+",
#          FractionBox[
#           RowBox[{"1", " ", "+", " ",
#            SuperscriptBox["t", "2"]}], "2"]}], ")"}], "2"],
#       RowBox[{"(",
#        SuperscriptBox["t", "3"], ")"}],
#       SuperscriptBox[
#        RowBox[{"(",
#         RowBox[{"1", "-",
#          RowBox[{"z",
#           RowBox[{"(",
#            RowBox[{"1", "-", "t"}], ")"}]}]}], ")"}], "2"]}], ",",
#      RowBox[{"{",
#       RowBox[{"t", ",", "0", ",", "1"}], "}"}], ",",
#      RowBox[{"Assumptions", "->",
#       RowBox[{
#        RowBox[{"Element", "[",
#         RowBox[{
#          RowBox[{"{",
#           RowBox[{"b", ",", "z"}], "}"}], ",", "Reals"}], "]"}], "&&",
#        RowBox[{
#         RowBox[{"{", "z", "}"}], "<", "1"}]}]}]}], "]"}], "]"}]}]], "Input",
#  CellChangeTimes->{{3.8871966515420856`*^9, 3.887196657849538*^9}, {
#    3.887197019461763*^9, 3.8871970202578783`*^9}, 3.887197391169403*^9,
#    3.8876346041182613`*^9, {3.8879047776300783`*^9, 3.887904807663855*^9}, {
#    3.887904924599154*^9, 3.887904942996567*^9}, 3.888148387380184*^9, {
#    3.908436037243232*^9, 3.9084362203498116`*^9}, {3.9084386916235085`*^9,
#    3.9084387068005824`*^9}, {3.90893016363597*^9, 3.908930164383273*^9}, {
#    3.908930685235114*^9, 3.908930715874014*^9}, {3.916798285178237*^9,
#    3.9167983134255676`*^9}, 3.9168322759634185`*^9, {3.9170049155580287`*^9,
#    3.9170049288534403`*^9}, {3.917005117718999*^9, 3.917005120095436*^9}, {
#    3.917010615233634*^9, 3.9170106247351904`*^9}, {3.97578291260178*^9,
#    3.975782924019198*^9}},
#  CellLabel->"In[2]:=",ExpressionUUID->"c2a2ebf4-0206-44c4-9e29-4fdecc16f29f"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-11"></a>
#
# <details>
# <summary>Original source cell 11; Output; source line 1353; group 9.2</summary>
#
# ```wolfram
# Cell[BoxData[
#  FractionBox[
#   RowBox[{
#    RowBox[{
#     SuperscriptBox["b", "2"], " ",
#     RowBox[{"(",
#      RowBox[{"1785", "+",
#       RowBox[{"z", " ",
#        RowBox[{"(",
#         RowBox[{
#          RowBox[{"-", "562"}], "+",
#          RowBox[{"79", " ", "z"}]}], ")"}]}], "+",
#       RowBox[{"42", " ",
#        SuperscriptBox["b", "2"], " ",
#        RowBox[{"(",
#         RowBox[{"15", "+",
#          RowBox[{
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"-", "6"}], "+", "z"}], ")"}], " ", "z"}]}], ")"}]}], "+",
#       RowBox[{"6", " ", "b", " ",
#        RowBox[{"(",
#         RowBox[{"350", "+",
#          RowBox[{"z", " ",
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"-", "124"}], "+",
#             RowBox[{"19", " ", "z"}]}], ")"}]}]}], ")"}]}]}], ")"}]}], "-",
#    RowBox[{"8", " ", "b", " ",
#     RowBox[{"(",
#      RowBox[{"1", "+", "b"}], ")"}], " ",
#     RowBox[{"(",
#      RowBox[{"432", "+",
#       RowBox[{"z", " ",
#        RowBox[{"(",
#         RowBox[{
#          RowBox[{"-", "129"}], "+",
#          RowBox[{"17", " ", "z"}]}], ")"}]}], "+",
#       RowBox[{"12", " ", "b", " ",
#        RowBox[{"(",
#         RowBox[{"21", "+",
#          RowBox[{
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"-", "7"}], "+", "z"}], ")"}], " ", "z"}]}], ")"}]}]}],
#      ")"}], " ",
#     RowBox[{"Log", "[",
#      RowBox[{"1", "+", "b"}], "]"}]}], "+",
#    RowBox[{"60", " ",
#     SuperscriptBox[
#      RowBox[{"(",
#       RowBox[{"1", "+", "b"}], ")"}], "2"], " ",
#     RowBox[{"(",
#      RowBox[{"28", "+",
#       RowBox[{
#        RowBox[{"(",
#         RowBox[{
#          RowBox[{"-", "8"}], "+", "z"}], ")"}], " ", "z"}]}], ")"}], " ",
#     SuperscriptBox[
#      RowBox[{"Log", "[",
#       RowBox[{"1", "+", "b"}], "]"}], "2"]}]}],
#   RowBox[{"10080", " ",
#    SuperscriptBox["b", "2"]}]]], "Output",
#  CellChangeTimes->{3.917005125207843*^9, 3.9170106298907447`*^9,
#   3.917023258560113*^9, 3.975783043630293*^9},
#  CellLabel->"Out[2]=",ExpressionUUID->"bdcc4e94-2033-481d-86bd-3b9faff3c74b"]
# ```
#
# </details>
