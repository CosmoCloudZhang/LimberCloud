# %% [markdown]
# # SS: Coefficient B02
#
# Readable edition of the original Mathematica derivation. Scientific cells remain in source order. Normalized power uses $p=1-P_1/P_2$ in the reading edition; original spellings and complete source cells are preserved in the appendix. Cached Wolfram outputs are transcribed results, not a fresh execution.
#
# [Original Mathematica notebook](Coefficient_B02.nb) · [Conversion inventory and notation ledger](../README.md)
#
# The displayed dimensional integrals, definitions, normalized I/J integrals, inputs and outputs follow the author's original sequence. No runtime data or Mathematica installation is needed to read this notebook.

# %% [markdown]
# [Source cell 1](#source-01), `InlineFormula`.
#
# $$
# B^{i = n < N, j = n+1 < N}_{\kappa \kappa, n}=B^{i = n+1 < N, j = n < N}_{\kappa \kappa, n}= \frac{9 \Omega_{\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \int_{\chi_{n}}^{\chi_{n + 1}} \mathrm{d} \chi \left( \frac{\chi_{n + 1}^2 - \chi^2}{2 \left( \chi_{n + 1} - \chi_{n} \right)} - \frac{\chi \chi_{n + 1}}{\left( \chi_{n + 1} - \chi_{n} \right)} \ln{\frac{\chi_{n + 1}}{\chi}} \right) \left( \frac{\chi_{n + 2}-\chi_{n + 1}}{2}-\frac{\chi \chi_{n + 2}}{\chi_{n + 2}-\chi_{n + 1}}\ln{\frac{\chi_{n + 2}}{\chi_{n + 1}}}+\frac{\chi_{n + 1}^2-2\chi_{n}\chi_{n + 1}+\chi^2}{2\left( \chi_{n + 1}-\chi_{n}  \right)}+\frac{\chi \chi_{n}}{\chi_{n + 1}-\chi_{n}}\ln{\frac{\chi_{n + 1}}{\chi}} \right) \left( \frac{\chi_{n + 1} - \chi}{\chi_{n + 1} - \chi_n} P_\ell^{n} + \frac{\chi - \chi_n}{\chi_{n + 1} - \chi_n} P_\ell^{n + 1} \right) \left(1 + \frac{\chi_{n + 1} - \chi}{\chi_{n + 1} - \chi_n} z_{n} + \frac{\chi - \chi_{n}}{\chi_{n + 1} - \chi_{n}} z_{n + 1} \right)^2
# $$

# %% [markdown]
# [Source cell 2](#source-02), `InlineFormula`.
#
# $$
# B^{i = 0, j = 1}_{\kappa \kappa,0}=B^{i = 1, j = 0} _{kappa \kappa, 0}= \frac{9 \Omega_{\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \int_{0}^{\chi_{1}} \mathrm{d} \chi \left( \frac{\chi_{1}^2 - \chi^2}{2  \chi_{1} } - \chi \ln{\frac{\chi_{1}}{\chi}} \right) \left( \frac{\chi_{2}-\chi_{1}}{2}-\frac{\chi \chi_{2}}{\chi_{2}-\chi_{1}}\ln{\frac{\chi_{2}}{\chi_{1}}}+\frac{\chi_{1}^2+\chi^2}{2 \chi_{1}} \right) \left( \frac{\chi^3}{\chi_{1}^3}P_\ell^{1} \right) \left(1 + \frac{\chi}{\chi_{1} } z_{1} \right)^2
# $$

# %% [markdown]
# [Source cell 3](#source-03), `InlineFormula`.
#
# $$
# t = \frac{\chi}{\chi_{n + 1}}
# $$
#
# $$
# p = \frac{P_\ell ^{n + 1}- P_\ell^{n}}{P_\ell^{n + 1}}
# $$
#
# $$
# z = \frac{z_{n + 1}- z_{n}}{1 + z_{n + 1}}
# $$
#
# $$
# a = \frac{\chi_{n + 1}- \chi_{n}}{\chi_{n + 1}}
# $$
#
# $$
# b = \frac{\chi_{n + 2}- \chi_{n + 1}}{\chi_{n + 1}}
# $$

# %% [markdown]
# [Source cell 4](#source-04), `InlineFormula`.
#
# $$
# B^{i = n < N, j = n+1 < N}_{\kappa \kappa, n}=B^{i = n+1 < N, j = n < N}_{\kappa \kappa,n} = \frac{9 \Omega_{\mathrm{m}, 0}^2 H_0^4}{4 c^4} \chi^3_{n + 1} P_\ell^{n + 1} (1 + z_{n + 1})^2 I_2
# $$

# %% [markdown]
# [Source cell 5](#source-05), `InlineFormula`.
#
# $$
# B^{i = 0, j = 1}_{\kappa \kappa, 0}=B^{i = 1, j = 0}_{\kappa \kappa, 0} = \frac{9 \Omega_{\mathrm{m}, 0}^2 H_0^4}{4 c^4} \chi^3_{1} P_\ell^{1} (1 + z_{1})^2 J_2
# $$

# %% [markdown]
# [Source cell 6](#source-06), `InlineFormula`.
#
# $$
# I_2 = \int_{1-a}^{1} \mathrm{d} t \: \left( \frac{1 - t^2}{2 a} + \frac{t \ln{t}}{a} \right) \left( \frac{b}{2}-\frac{t \left( b+1\right)}{b} \ln{\left( b+1 \right)} + 1 - \frac{1-t^2}{2a}-\frac{t \left(  1-a \right) }{a} \ln{t}  \right) \left( 1 - \frac{p}{a} (1 - t) \right) \left( 1 - \frac{z}{a} (1 - t) \right)^2
# $$

# %% [markdown]
# [Source cell 7](#source-07), `InlineFormula`.
#
# $$
# J_2 = \int_{0}^{1} \mathrm{d} t \: \left( \frac{1 - t^2}{2} + t \ln{t} \right) \left( \frac{b}{2}-\frac{t \left( b+1\right)}{b} \ln{\left( b+1 \right)}+\frac{1+t^2}{2}  \right) t^3 \left( 1 - z (1 - t) \right)^2
# $$

# %% [markdown]
# ### Symbolic input
#
# [Source cell 8](#source-08), `Input`.
#
# Corrected notation; Wolfram Language shown as text.
#
# ```wolfram
# I2= FullSimplify[Integrate[((1 - (t)^(2))/(2 a)+(t)/(a)Log[t])((b)/(2)-(t (b+1))/(b) Log[b+1]+1-(1 - (t)^(2))/(2 a)-(t(1-a))/(a)Log[t])(1-(p)/(a)(1-t))((1-(z)/(a)(1-t)))^(2),{t,1-a,1},Assumptions->Element[{a,b,p,z},Reals]&&{a,p,z}<1]]
# ```

# %% [markdown]
# ### Saved symbolic output
#
# [Source cell 9](#source-09), `Output`.
#
# Transcribed cached result, with the noted symbol renaming only.
#
# $$
# -\frac{1}{4\,{a}^{5}\,b}(\frac{1}{15}\,{(-1+a)}^{4}\,b\,(5\,{a}^{2}\,(p+a\,(-4+3\,p))-2\,a\,(2\,p+a\,(-5+6\,p+3\,a\,(-5+4\,p)))\,z+(-2\,a\,(1+3\,a+6\,{a}^{2})+p+a\,(3+2\,a\,(3+5\,a))\,p)\,{z}^{2})\,{\log [1-a]}^{2}+\frac{1}{3150}{(-1+a)}^{2}\,\log [1-a]\,(b\,(35\,{a}^{2}\,(-5\,a\,(2+a\,(23+a\,(-52+9\,a)-18\,b))+(7+a\,(28+a\,(19+36\,(-5+a)\,a-60\,b)-30\,b))\,p)+14\,a\,(5\,a\,(7+a\,(28+a\,(19+36\,(-5+a)\,a-60\,b)-30\,b))-26\,p+a\,(-56+2\,a\,(-13+3\,a\,(4+(114-25\,a)\,a))+75\,(1+a\,(2+3\,a))\,b)\,p)\,z+(7\,a\,(-26-2\,a\,(28+a\,(13+3\,a\,(-4+a\,(-114+25\,a))))+75\,a\,(1+a\,(2+3\,a))\,b)+(141+a\,(201+51\,a-169\,{a}^{2}-424\,{a}^{3}-3850\,{a}^{4}+900\,{a}^{5}-315\,(1+a\,(2+a\,(3+4\,a)))\,b))\,p)\,{z}^{2})-210\,(-1+a)\,a\,(1+b)\,(5\,{a}^{2}\,(p+a\,(-4+3\,p))-2\,a\,(2\,p+a\,(-5+6\,p+3\,a\,(-5+4\,p)))\,z+(-2\,a\,(1+3\,a+6\,{a}^{2})+p+a\,(3+2\,a\,(3+5\,a))\,p)\,{z}^{2})\,\log [1+b])-\frac{1}{1323000}a\,(b\,(245\,{a}^{2}\,(-420\,p+20\,{a}^{2}\,(-60+45\,b\,(-6+p)+62\,p)+9\,{a}^{5}\,(-195+148\,p)+5\,{a}^{3}\,(-830+60\,b\,(27-16\,p)+193\,p)+150\,a\,(4+(5+12\,b)\,p)+2\,{a}^{4}\,(3725-2322\,p+225\,b\,(-4+3\,p)))-14\,a\,(35\,a\,(420+a\,(-150\,(5+12\,b)+a\,(-20\,(62+45\,b)+a\,(-965+4800\,b-18\,a\,(-258+74\,a+75\,b)))))+(-10920+2\,a\,(9030+a\,(10360+a\,(7805+6\,a\,(1008+a\,(-9688+3125\,a)))))+525\,a\,(60+a\,(30+a\,(20+9\,a\,(-25+8\,a))))\,b)\,p)\,z+(7\,a\,(10920-2\,a\,(9030+a\,(10360+a\,(7805+6\,a\,(1008+a\,(-9688+3125\,a)))))-525\,a\,(60+a\,(30+a\,(20+9\,a\,(-25+8\,a))))\,b)+(-59220+a\,(92610+85470\,a+62685\,{a}^{2}+48111\,{a}^{3}+38584\,{a}^{4}-629500\,{a}^{5}+219375\,{a}^{6}+2205\,(60+a\,(30+a\,(20+a\,(15+4\,a\,(-72+25\,a)))))\,b))\,p)\,{z}^{2})+210\,a\,(1+b)\,(-210\,a\,(p\,(-8+z)-4\,z)\,z-420\,p\,{z}^{2}-35\,{a}^{3}\,(30\,(-8+p)+4\,(15-4\,p)\,z+(-8+3\,p)\,{z}^{2})+14\,{a}^{4}\,(-1500+850\,p+5\,(340-117\,z)\,z+6\,p\,z\,(-195+74\,z))-140\,{a}^{2}\,(-3\,(-10+z)\,z+p\,(15+(-6+z)\,z))+30\,{a}^{6}\,(4\,p\,(21+5\,z\,(-7+3\,z))-7\,(15+2\,z\,(-12+5\,z)))-7\,{a}^{5}\,(-2200+18\,(175-68\,z)\,z+p\,(1575+8\,z\,(-306+125\,z))))\,\log [1+b]))
# $$

# %% [markdown]
# ### Symbolic input
#
# [Source cell 10](#source-10), `Input`.
#
# Corrected notation; Wolfram Language shown as text.
#
# ```wolfram
# J2= FullSimplify[Integrate[((1 - (t)^(2))/(2)+t Log[t])((b)/(2)-(t (b+1))/(b) Log[b+1]+(1 + (t)^(2))/(2))((t)^(3))((1-z(1-t)))^(2),{t,0,1},Assumptions->Element[{b,z},Reals]&&{z}<1]]
# ```

# %% [markdown]
# ### Saved symbolic output
#
# [Source cell 11](#source-11), `Output`.
#
# Transcribed cached result, with the noted symbol renaming only.
#
# $$
# \frac{b\,(6642+z\,(-6669+1867\,z)+18\,b\,(294+z\,(-308+89\,z)))-45\,(1+b)\,(112+z\,(-104+27\,z))\,\log [1+b]}{6350400\,b}
# $$

# %% [markdown]
# ## Exact original content cells
#
# All source content cells follow in their original order, including original spellings, assumptions, saved outputs and cell metadata. Frontend-level metadata remains in the unchanged `.nb` file. Expand an entry to inspect its Wolfram box source.

# %% [markdown]
# <a id="source-01"></a>
#
# <details>
# <summary>Original source cell 1; InlineFormula; source line 21; group 1</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Integral]",
#          SubscriptBox["\[Chi]",
#           StyleBox["n", "TI"]],
#          SubscriptBox["\[Chi]",
#           RowBox[{
#             StyleBox["n", "TI"], "+", "1"}]]],
#         StyleBox["d", FontSlant -> "Plain"], "\[Chi]",
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubsuperscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}], "2"], "-",
#                SuperscriptBox["\[Chi]", "2"]}],
#              RowBox[{"2", "(",
#                RowBox[{
#                  SubscriptBox["\[Chi]",
#                   RowBox[{
#                     StyleBox["n", "TI"], "+", "1"}]], "-",
#                  SubscriptBox["\[Chi]",
#                   StyleBox["n", "TI"]]}], ")"}]], "-",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]],
#              RowBox[{"(",
#                RowBox[{
#                  SubscriptBox["\[Chi]",
#                   RowBox[{
#                     StyleBox["n", "TI"], "+", "1"}]], "-",
#                  SubscriptBox["\[Chi]",
#                   StyleBox["n", "TI"]]}], ")"}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]], "\[Chi]"]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "2"}]], "-",
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]]}], "2"], "-",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "2"}]],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "2"}]], "-",
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "2"}]],
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]]], "+",
#             FractionBox[
#              RowBox[{
#                SubsuperscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}], "2"], "-", "2",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]],
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "+",
#                SuperscriptBox["\[Chi]", "2"]}],
#              RowBox[{"2", "(",
#                RowBox[{
#                  SubscriptBox["\[Chi]",
#                   RowBox[{
#                     StyleBox["n", "TI"], "+", "1"}]], "-",
#                  SubscriptBox["\[Chi]",
#                   StyleBox["n", "TI"]]}], ")"}]], "+",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]",
#               StyleBox["n", "TI"]],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]",
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]], "\[Chi]"]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-", "\[Chi]"}],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}]],
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              StyleBox["n", "TI"]], "+",
#             FractionBox[
#              RowBox[{"\[Chi]", "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}],
#              RowBox[{
#                SubscriptBox["\[Chi]",
#                 RowBox[{
#                   StyleBox["n", "TI"], "+", "1"}]], "-",
#                SubscriptBox["\[Chi]",
#                 StyleBox["n", "TI"]]}]],
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}], ")"}],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              FractionBox[
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-", "\[Chi]"}],
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}]],
#              SubscriptBox[
#               StyleBox["z", "TI"],
#               StyleBox["n", "TI"]], "+",
#              FractionBox[
#               RowBox[{"\[Chi]", "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}],
#               RowBox[{
#                 SubscriptBox["\[Chi]",
#                  RowBox[{
#                    StyleBox["n", "TI"], "+", "1"}]], "-",
#                 SubscriptBox["\[Chi]",
#                  StyleBox["n", "TI"]]}]],
#              SubscriptBox[
#               StyleBox["z", "TI"],
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]]}], ")"}], "2"]}],
#       TraditionalForm], "errors" -> {}, "input" ->
#     "B^{i = n < N, j = n+1 < N}_{\\kappa \\kappa, n}=B^{i = n+1 < N, j = n < \
# N}_{\\kappa \\kappa, n}= \\frac{9 \\Omega_{\\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \
# \\int_{\\chi_{n}}^{\\chi_{n + 1}} \\mathrm{d} \\chi \\left( \\frac{\\chi_{n + \
# 1}^2 - \\chi^2}{2 \\left( \\chi_{n + 1} - \\chi_{n} \\right)} - \\frac{\\chi \
# \\chi_{n + 1}}{\\left( \\chi_{n + 1} - \\chi_{n} \\right)} \
# \\ln{\\frac{\\chi_{n + 1}}{\\chi}} \\right) \\left( \\frac{\\chi_{n + \
# 2}-\\chi_{n + 1}}{2}-\\frac{\\chi \\chi_{n + 2}}{\\chi_{n + 2}-\\chi_{n + 1}}\
# \\ln{\\frac{\\chi_{n + 2}}{\\chi_{n + 1}}}+\\frac{\\chi_{n + \
# 1}^2-2\\chi_{n}\\chi_{n + 1}+\\chi^2}{2\\left( \\chi_{n + 1}-\\chi_{n}  \
# \\right)}+\\frac{\\chi \\chi_{n}}{\\chi_{n + \
# 1}-\\chi_{n}}\\ln{\\frac{\\chi_{n + 1}}{\\chi}} \\right) \\left( \
# \\frac{\\chi_{n + 1} - \\chi}{\\chi_{n + 1} - \\chi_n} P_\\ell^{n} + \
# \\frac{\\chi - \\chi_n}{\\chi_{n + 1} - \\chi_n} P_\\ell^{n + 1} \\right) \
# \\left(1 + \\frac{\\chi_{n + 1} - \\chi}{\\chi_{n + 1} - \\chi_n} z_{n} + \
# \\frac{\\chi - \\chi_{n}}{\\chi_{n + 1} - \\chi_{n}} z_{n + 1} \\right)^2",
#     "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"60447724-e9a2-4715-a247-3cd8aa885fdd"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.975771063168355*^9},ExpressionUUID->"4bcd4545-f7ad-4dcc-a313-\
# da16808a0af1"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-02"></a>
#
# <details>
# <summary>Original source cell 2; InlineFormula; source line 238; group 2</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",", "0"}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]", "0", ",",
#            StyleBox["j", "TI"], "\[LongEqual]", "1"}]], "\[LongEqual]",
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{
#            StyleBox["k", "TI"],
#            StyleBox["a", "TI"],
#            StyleBox["p", "TI"],
#            StyleBox["p", "TI"],
#            StyleBox["a", "TI"], "\[Kappa]", ",", "0"}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]", "1", ",",
#            StyleBox["j", "TI"], "\[LongEqual]", "0"}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Integral]", "0",
#          SubscriptBox["\[Chi]", "1"]],
#         StyleBox["d", FontSlant -> "Plain"], "\[Chi]",
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubsuperscriptBox["\[Chi]", "1", "2"], "-",
#                SuperscriptBox["\[Chi]", "2"]}],
#              RowBox[{"2",
#                SubscriptBox["\[Chi]", "1"]}]], "-", "\[Chi]", "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]", "1"], "\[Chi]"]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{
#                SubscriptBox["\[Chi]", "2"], "-",
#                SubscriptBox["\[Chi]", "1"]}], "2"], "-",
#             FractionBox[
#              SubscriptBox["\[Chi]\[Chi]", "2"],
#              RowBox[{
#                SubscriptBox["\[Chi]", "2"], "-",
#                SubscriptBox["\[Chi]", "1"]}]], "ln",
#             FractionBox[
#              SubscriptBox["\[Chi]", "2"],
#              SubscriptBox["\[Chi]", "1"]], "+",
#             FractionBox[
#              RowBox[{
#                SubsuperscriptBox["\[Chi]", "1", "2"], "+",
#                SuperscriptBox["\[Chi]", "2"]}],
#              RowBox[{"2",
#                SubscriptBox["\[Chi]", "1"]}]]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              SuperscriptBox["\[Chi]", "3"],
#              SubsuperscriptBox["\[Chi]", "1", "3"]],
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]", "1"]}], ")"}],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              FractionBox["\[Chi]",
#               SubscriptBox["\[Chi]", "1"]],
#              SubscriptBox[
#               StyleBox["z", "TI"], "1"]}], ")"}], "2"]}], TraditionalForm],
#     "errors" -> {}, "input" ->
#     "B^{i = 0, j = 1}_{\\kappa \\kappa,0}=B^{i = 1, j = 0} _{kappa \\kappa, \
# 0}= \\frac{9 \\Omega_{\\mathrm{m}, 0}^2 H_ 0^4}{4 c^4} \\int_{0}^{\\chi_{1}} \
# \\mathrm{d} \\chi \\left( \\frac{\\chi_{1}^2 - \\chi^2}{2  \\chi_{1} } - \
# \\chi \\ln{\\frac{\\chi_{1}}{\\chi}} \\right) \\left( \
# \\frac{\\chi_{2}-\\chi_{1}}{2}-\\frac{\\chi \
# \\chi_{2}}{\\chi_{2}-\\chi_{1}}\\ln{\\frac{\\chi_{2}}{\\chi_{1}}}+\\frac{\\\
# chi_{1}^2+\\chi^2}{2 \\chi_{1}} \\right) \\left( \
# \\frac{\\chi^3}{\\chi_{1}^3}P_\\ell^{1} \\right) \\left(1 + \
# \\frac{\\chi}{\\chi_{1} } z_{1} \\right)^2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"b4906995-bab4-400e-b1d3-a10b2c91b41f"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.975771085670609*^9},ExpressionUUID->"36bb7ad8-e71a-476f-a6bd-\
# 0d07aae73bda"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-03"></a>
#
# <details>
# <summary>Original source cell 3; InlineFormula; source line 333; group 3</summary>
#
# ```wolfram
# Cell[TextData[{
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["t", "TI"], "\[LongEqual]",
#          FractionBox["\[Chi]",
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" -> "t = \\frac{\\chi}{\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "4912d5c3-8324-4d69-b599-aa8184e5949f"],
#  ",  ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["p", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]], "-",
#             SubsuperscriptBox[
#              StyleBox["P", "TI"], "\[ScriptL]",
#              StyleBox["n", "TI"]]}],
#           SubsuperscriptBox[
#            StyleBox["P", "TI"], "\[ScriptL]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "p = \\frac{P_\\ell ^{n + 1}- P_\\ell^{n}}{P_\\ell^{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "2eee0d46-505d-4d0b-a58e-a80e9d4b755e"],
#  ", ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["z", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox[
#              StyleBox["z", "TI"],
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]], "-",
#             SubscriptBox[
#              StyleBox["z", "TI"],
#              StyleBox["n", "TI"]]}],
#           RowBox[{"1", "+",
#             SubscriptBox[
#              StyleBox["z", "TI"],
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}]]}], TraditionalForm],
#      "errors" -> {}, "input" -> "z = \\frac{z_{n + 1}- z_{n}}{1 + z_{n + 1}}",
#       "state" -> "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "be8b5f05-d2fa-477e-8c94-d8b2004eff86"],
#  ",",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["a", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]], "-",
#             SubscriptBox["\[Chi]",
#              StyleBox["n", "TI"]]}],
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "a = \\frac{\\chi_{n + 1}- \\chi_{n}}{\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "cd5bc0ef-6bde-46f9-b2d0-a308f8f0a448"],
#  ", ",
#  Cell[BoxData[
#   FormBox[
#    TemplateBox[<|"boxes" -> FormBox[
#        RowBox[{
#          StyleBox["b", "TI"], "\[LongEqual]",
#          FractionBox[
#           RowBox[{
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "2"}]], "-",
#             SubscriptBox["\[Chi]",
#              RowBox[{
#                StyleBox["n", "TI"], "+", "1"}]]}],
#           SubscriptBox["\[Chi]",
#            RowBox[{
#              StyleBox["n", "TI"], "+", "1"}]]]}], TraditionalForm],
#      "errors" -> {}, "input" ->
#      "b = \\frac{\\chi_{n + 2}- \\chi_{n + 1}}{\\chi_{n + 1}}", "state" ->
#      "Boxes"|>,
#     "TeXAssistantTemplate"], TraditionalForm]],ExpressionUUID->
#   "ce760377-6b1a-44ec-9037-03984fbdc85d"]
# }], "InlineFormula",
#  CellChangeTimes->{{3.887196302307176*^9, 3.887196331440764*^9}, {
#    3.887196362536772*^9, 3.887196382134186*^9}, {3.9084206984864616`*^9,
#    3.9084207040669937`*^9}, 3.9084340401865296`*^9, 3.9084351731002855`*^9,
#    3.9084355812628045`*^9, {3.908925642333192*^9,
#    3.9089256585900345`*^9}},ExpressionUUID->"7b6246ea-d307-486a-90da-\
# c05c2c9b0953"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-04"></a>
#
# <details>
# <summary>Original source cell 4; InlineFormula; source line 446; group 4</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",",
#            StyleBox["n", "TI"]}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "+", "1", "<",
#            StyleBox["N", "TI"], ",",
#            StyleBox["j", "TI"], "\[LongEqual]",
#            StyleBox["n", "TI"], "<",
#            StyleBox["N", "TI"]}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Chi]",
#          RowBox[{
#            StyleBox["n", "TI"], "+", "1"}], "3"],
#         SubsuperscriptBox[
#          StyleBox["P", "TI"], "\[ScriptL]",
#          RowBox[{
#            StyleBox["n", "TI"], "+", "1"}]],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              SubscriptBox[
#               StyleBox["z", "TI"],
#               RowBox[{
#                 StyleBox["n", "TI"], "+", "1"}]]}], ")"}], "2"],
#         SubscriptBox[
#          StyleBox["I", "TI"], "2"]}], TraditionalForm], "errors" -> {},
#     "input" ->
#     "B^{i = n < N, j = n+1 < N}_{\\kappa \\kappa, n}=B^{i = n+1 < N, j = n < \
# N}_{\\kappa \\kappa,n} = \\frac{9 \\Omega_{\\mathrm{m}, 0}^2 H_0^4}{4 c^4} \
# \\chi^3_{n + 1} P_\\ell^{n + 1} (1 + z_{n + 1})^2 I_2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"042353f9-a993-4e9b-847c-3ce95bebc683"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196401920412*^9, {3.9084337680750885`*^9,
#    3.908433770987523*^9}},ExpressionUUID->"21cd44dd-49c8-44f7-a1b3-\
# e5707dd0452b"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-05"></a>
#
# <details>
# <summary>Original source cell 5; InlineFormula; source line 510; group 5</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",", "0"}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]", "0", ",",
#            StyleBox["j", "TI"], "\[LongEqual]", "1"}]], "\[LongEqual]",
#         SubsuperscriptBox[
#          StyleBox["B", "TI"],
#          RowBox[{"\[Kappa]\[Kappa]", ",", "0"}],
#          RowBox[{
#            StyleBox["i", "TI"], "\[LongEqual]", "1", ",",
#            StyleBox["j", "TI"], "\[LongEqual]", "0"}]], "\[LongEqual]",
#         FractionBox[
#          RowBox[{"9",
#            SubsuperscriptBox["\[CapitalOmega]",
#             RowBox[{
#               StyleBox["m", FontSlant -> "Plain"], ",", "0"}], "2"],
#            SubsuperscriptBox[
#             StyleBox["H", "TI"], "0", "4"]}],
#          RowBox[{"4",
#            SuperscriptBox[
#             StyleBox["c", "TI"], "4"]}]],
#         SubsuperscriptBox["\[Chi]", "1", "3"],
#         SubsuperscriptBox[
#          StyleBox["P", "TI"], "\[ScriptL]", "1"],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "+",
#              SubscriptBox[
#               StyleBox["z", "TI"], "1"]}], ")"}], "2"],
#         SubscriptBox[
#          StyleBox["J", "TI"], "2"]}], TraditionalForm], "errors" -> {},
#     "input" ->
#     "B^{i = 0, j = 1}_{\\kappa \\kappa, 0}=B^{i = 1, j = 0}_{\\kappa \\kappa, \
# 0} = \\frac{9 \\Omega_{\\mathrm{m}, 0}^2 H_0^4}{4 c^4} \\chi^3_{1} \
# P_\\ell^{1} (1 + z_{1})^2 J_2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"726e6979-d034-4145-88c3-cbf42673e522"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196401920412*^9, {3.9084337680750885`*^9,
#    3.908433770987523*^9}},ExpressionUUID->"4ea3e83e-e7ca-439f-b82b-\
# 815a19f3327b"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-06"></a>
#
# <details>
# <summary>Original source cell 6; InlineFormula; source line 558; group 6</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubscriptBox[
#          StyleBox["I", "TI"], "2"], "\[LongEqual]",
#         SubsuperscriptBox["\[Integral]",
#          RowBox[{"1", "-",
#            StyleBox["a", "TI"]}], "1"],
#         StyleBox["d", FontSlant -> "Plain"],
#         StyleBox["t", "TI"], " ",
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{"1", "-",
#                SuperscriptBox[
#                 StyleBox["t", "TI"], "2"]}],
#              RowBox[{"2",
#                StyleBox["a", "TI"]}]], "+",
#             FractionBox[
#              RowBox[{
#                StyleBox["t", "TI"], "ln",
#                StyleBox["t", "TI"]}],
#              StyleBox["a", "TI"]]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              StyleBox["b", "TI"], "2"], "-",
#             FractionBox[
#              RowBox[{
#                StyleBox["t", "TI"], "(",
#                RowBox[{
#                  StyleBox["b", "TI"], "+", "1"}], ")"}],
#              StyleBox["b", "TI"]], "ln",
#             RowBox[{"(",
#               RowBox[{
#                 StyleBox["b", "TI"], "+", "1"}], ")"}], "+", "1", "-",
#             FractionBox[
#              RowBox[{"1", "-",
#                SuperscriptBox[
#                 StyleBox["t", "TI"], "2"]}],
#              RowBox[{"2",
#                StyleBox["a", "TI"]}]], "-",
#             FractionBox[
#              RowBox[{
#                StyleBox["t", "TI"], "(",
#                RowBox[{"1", "-",
#                  StyleBox["a", "TI"]}], ")"}],
#              StyleBox["a", "TI"]], "ln",
#             StyleBox["t", "TI"]}], ")"}],
#         RowBox[{"(",
#           RowBox[{"1", "-",
#             FractionBox[
#              StyleBox["p", "TI"],
#              StyleBox["a", "TI"]],
#             RowBox[{"(",
#               RowBox[{"1", "-",
#                 StyleBox["t", "TI"]}], ")"}]}], ")"}],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "-",
#              FractionBox[
#               StyleBox["z", "TI"],
#               StyleBox["a", "TI"]],
#              RowBox[{"(",
#                RowBox[{"1", "-",
#                  StyleBox["t", "TI"]}], ")"}]}], ")"}], "2"]}],
#       TraditionalForm], "errors" -> {}, "input" ->
#     "I_2 = \\int_{1-a}^{1} \\mathrm{d} t \\: \\left( \\frac{1 - t^2}{2 a} + \
# \\frac{t \\ln{t}}{a} \\right) \\left( \\frac{b}{2}-\\frac{t \\left( \
# b+1\\right)}{b} \\ln{\\left( b+1 \\right)} + 1 - \\frac{1-t^2}{2a}-\\frac{t \
# \\left(  1-a \\right) }{a} \\ln{t}  \\right) \\left( 1 - \\frac{p}{a} (1 - t) \
# \\right) \\left( 1 - \\frac{z}{a} (1 - t) \\right)^2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"f8d8d33b-26e6-44a7-ab4c-a2f5f26c6a82"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196539368146*^9},ExpressionUUID->"2e461cf4-f0f3-4eef-ba1c-\
# 97aa73b03444"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-07"></a>
#
# <details>
# <summary>Original source cell 7; InlineFormula; source line 638; group 7</summary>
#
# ```wolfram
# Cell[TextData[Cell[BoxData[
#  FormBox[
#   TemplateBox[<|"boxes" -> FormBox[
#       RowBox[{
#         SubscriptBox[
#          StyleBox["J", "TI"], "2"], "\[LongEqual]",
#         SubsuperscriptBox["\[Integral]", "0", "1"],
#         StyleBox["d", FontSlant -> "Plain"],
#         StyleBox["t", "TI"], " ",
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              RowBox[{"1", "-",
#                SuperscriptBox[
#                 StyleBox["t", "TI"], "2"]}], "2"], "+",
#             StyleBox["t", "TI"], "ln",
#             StyleBox["t", "TI"]}], ")"}],
#         RowBox[{"(",
#           RowBox[{
#             FractionBox[
#              StyleBox["b", "TI"], "2"], "-",
#             FractionBox[
#              RowBox[{
#                StyleBox["t", "TI"], "(",
#                RowBox[{
#                  StyleBox["b", "TI"], "+", "1"}], ")"}],
#              StyleBox["b", "TI"]], "ln",
#             RowBox[{"(",
#               RowBox[{
#                 StyleBox["b", "TI"], "+", "1"}], ")"}], "+",
#             FractionBox[
#              RowBox[{"1", "+",
#                SuperscriptBox[
#                 StyleBox["t", "TI"], "2"]}], "2"]}], ")"}],
#         SuperscriptBox[
#          StyleBox["t", "TI"], "3"],
#         SuperscriptBox[
#          RowBox[{"(",
#            RowBox[{"1", "-",
#              StyleBox["z", "TI"],
#              RowBox[{"(",
#                RowBox[{"1", "-",
#                  StyleBox["t", "TI"]}], ")"}]}], ")"}], "2"]}],
#       TraditionalForm], "errors" -> {}, "input" ->
#     "J_2 = \\int_{0}^{1} \\mathrm{d} t \\: \\left( \\frac{1 - t^2}{2} + t \
# \\ln{t} \\right) \\left( \\frac{b}{2}-\\frac{t \\left( b+1\\right)}{b} \
# \\ln{\\left( b+1 \\right)}+\\frac{1+t^2}{2}  \\right) t^3 \\left( 1 - z (1 - \
# t) \\right)^2", "state" -> "Boxes"|>,
#    "TeXAssistantTemplate"],
#   TraditionalForm]],ExpressionUUID->"8e545c25-0b90-40a3-94c8-8a94349bd35b"]], \
# "InlineFormula",
#  CellChangeTimes->{
#   3.887196539368146*^9},ExpressionUUID->"abccd9fa-45e5-42fa-bc13-\
# 3fd24298d079"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-08"></a>
#
# <details>
# <summary>Original source cell 8; Input; source line 695; group 8.1</summary>
#
# ```wolfram
# Cell[BoxData[
#  RowBox[{"I2", "=", " ",
#   RowBox[{"FullSimplify", "[",
#    RowBox[{"Integrate", "[",
#     RowBox[{
#      RowBox[{
#       RowBox[{"(",
#        RowBox[{
#         FractionBox[
#          RowBox[{"1", " ", "-", " ",
#           SuperscriptBox["t", "2"]}],
#          RowBox[{"2", " ", "a"}]], "+",
#         RowBox[{
#          FractionBox["t", "a"],
#          RowBox[{"Log", "[", "t", "]"}]}]}], ")"}],
#       RowBox[{"(",
#        RowBox[{
#         FractionBox["b", "2"], "-",
#         RowBox[{
#          FractionBox[
#           RowBox[{"t", " ",
#            RowBox[{"(",
#             RowBox[{"b", "+", "1"}], ")"}]}], "b"], " ",
#          RowBox[{"Log", "[",
#           RowBox[{"b", "+", "1"}], "]"}]}], "+", "1", "-",
#         FractionBox[
#          RowBox[{"1", " ", "-", " ",
#           SuperscriptBox["t", "2"]}],
#          RowBox[{"2", " ", "a"}]], "-",
#         RowBox[{
#          FractionBox[
#           RowBox[{"t",
#            RowBox[{"(",
#             RowBox[{"1", "-", "a"}], ")"}]}], "a"],
#          RowBox[{"Log", "[", "t", "]"}]}]}], ")"}],
#       RowBox[{"(",
#        RowBox[{"1", "-",
#         RowBox[{
#          FractionBox["p", "a"],
#          RowBox[{"(",
#           RowBox[{"1", "-", "t"}], ")"}]}]}], ")"}],
#       SuperscriptBox[
#        RowBox[{"(",
#         RowBox[{"1", "-",
#          RowBox[{
#           FractionBox["z", "a"],
#           RowBox[{"(",
#            RowBox[{"1", "-", "t"}], ")"}]}]}], ")"}], "2"]}], ",",
#      RowBox[{"{",
#       RowBox[{"t", ",",
#        RowBox[{"1", "-", "a"}], ",", "1"}], "}"}], ",",
#      RowBox[{"Assumptions", "->",
#       RowBox[{
#        RowBox[{"Element", "[",
#         RowBox[{
#          RowBox[{"{",
#           RowBox[{"a", ",", "b", ",", "p", ",", "z"}], "}"}], ",", "Reals"}],
#         "]"}], "&&",
#        RowBox[{
#         RowBox[{"{",
#          RowBox[{"a", ",", "p", ",", "z"}], "}"}], "<", "1"}]}]}]}], "]"}],
#    "]"}]}]], "Input",
#  CellChangeTimes->{{3.9167379500982203`*^9, 3.916737950175173*^9}, {
#   3.975776984588429*^9, 3.975777013603601*^9}},
#  CellLabel->"In[1]:=",ExpressionUUID->"c29dcc11-f3fd-4874-ade0-5f321327fdef"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-09"></a>
#
# <details>
# <summary>Original source cell 9; Output; source line 761; group 8.2</summary>
#
# ```wolfram
# Cell[BoxData[
#  RowBox[{"-",
#   RowBox[{
#    FractionBox["1",
#     RowBox[{"4", " ",
#      SuperscriptBox["a", "5"], " ", "b"}]],
#    RowBox[{"(",
#     RowBox[{
#      RowBox[{
#       FractionBox["1", "15"], " ",
#       SuperscriptBox[
#        RowBox[{"(",
#         RowBox[{
#          RowBox[{"-", "1"}], "+", "a"}], ")"}], "4"], " ", "b", " ",
#       RowBox[{"(",
#        RowBox[{
#         RowBox[{"5", " ",
#          SuperscriptBox["a", "2"], " ",
#          RowBox[{"(",
#           RowBox[{"p", "+",
#            RowBox[{"a", " ",
#             RowBox[{"(",
#              RowBox[{
#               RowBox[{"-", "4"}], "+",
#               RowBox[{"3", " ", "p"}]}], ")"}]}]}], ")"}]}], "-",
#         RowBox[{"2", " ", "a", " ",
#          RowBox[{"(",
#           RowBox[{
#            RowBox[{"2", " ", "p"}], "+",
#            RowBox[{"a", " ",
#             RowBox[{"(",
#              RowBox[{
#               RowBox[{"-", "5"}], "+",
#               RowBox[{"6", " ", "p"}], "+",
#               RowBox[{"3", " ", "a", " ",
#                RowBox[{"(",
#                 RowBox[{
#                  RowBox[{"-", "5"}], "+",
#                  RowBox[{"4", " ", "p"}]}], ")"}]}]}], ")"}]}]}], ")"}], " ",
#          "z"}], "+",
#         RowBox[{
#          RowBox[{"(",
#           RowBox[{
#            RowBox[{
#             RowBox[{"-", "2"}], " ", "a", " ",
#             RowBox[{"(",
#              RowBox[{"1", "+",
#               RowBox[{"3", " ", "a"}], "+",
#               RowBox[{"6", " ",
#                SuperscriptBox["a", "2"]}]}], ")"}]}], "+", "p", "+",
#            RowBox[{"a", " ",
#             RowBox[{"(",
#              RowBox[{"3", "+",
#               RowBox[{"2", " ", "a", " ",
#                RowBox[{"(",
#                 RowBox[{"3", "+",
#                  RowBox[{"5", " ", "a"}]}], ")"}]}]}], ")"}], " ", "p"}]}],
#           ")"}], " ",
#          SuperscriptBox["z", "2"]}]}], ")"}], " ",
#       SuperscriptBox[
#        RowBox[{"Log", "[",
#         RowBox[{"1", "-", "a"}], "]"}], "2"]}], "+",
#      RowBox[{
#       FractionBox["1", "3150"],
#       RowBox[{
#        SuperscriptBox[
#         RowBox[{"(",
#          RowBox[{
#           RowBox[{"-", "1"}], "+", "a"}], ")"}], "2"], " ",
#        RowBox[{"Log", "[",
#         RowBox[{"1", "-", "a"}], "]"}], " ",
#        RowBox[{"(",
#         RowBox[{
#          RowBox[{"b", " ",
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"35", " ",
#              SuperscriptBox["a", "2"], " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{
#                 RowBox[{"-", "5"}], " ", "a", " ",
#                 RowBox[{"(",
#                  RowBox[{"2", "+",
#                   RowBox[{"a", " ",
#                    RowBox[{"(",
#                     RowBox[{"23", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "52"}], "+",
#                     RowBox[{"9", " ", "a"}]}], ")"}]}], "-",
#                     RowBox[{"18", " ", "b"}]}], ")"}]}]}], ")"}]}], "+",
#                RowBox[{
#                 RowBox[{"(",
#                  RowBox[{"7", "+",
#                   RowBox[{"a", " ",
#                    RowBox[{"(",
#                     RowBox[{"28", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"19", "+",
#                     RowBox[{"36", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "5"}], "+", "a"}], ")"}], " ", "a"}], "-",
#                     RowBox[{"60", " ", "b"}]}], ")"}]}], "-",
#                     RowBox[{"30", " ", "b"}]}], ")"}]}]}], ")"}], " ",
#                 "p"}]}], ")"}]}], "+",
#             RowBox[{"14", " ", "a", " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"5", " ", "a", " ",
#                 RowBox[{"(",
#                  RowBox[{"7", "+",
#                   RowBox[{"a", " ",
#                    RowBox[{"(",
#                     RowBox[{"28", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"19", "+",
#                     RowBox[{"36", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "5"}], "+", "a"}], ")"}], " ", "a"}], "-",
#                     RowBox[{"60", " ", "b"}]}], ")"}]}], "-",
#                     RowBox[{"30", " ", "b"}]}], ")"}]}]}], ")"}]}], "-",
#                RowBox[{"26", " ", "p"}], "+",
#                RowBox[{"a", " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "56"}], "+",
#                   RowBox[{"2", " ", "a", " ",
#                    RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "13"}], "+",
#                     RowBox[{"3", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{"4", "+",
#                     RowBox[{
#                     RowBox[{"(",
#                     RowBox[{"114", "-",
#                     RowBox[{"25", " ", "a"}]}], ")"}], " ", "a"}]}],
#                     ")"}]}]}], ")"}]}], "+",
#                   RowBox[{"75", " ",
#                    RowBox[{"(",
#                     RowBox[{"1", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"2", "+",
#                     RowBox[{"3", " ", "a"}]}], ")"}]}]}], ")"}], " ", "b"}]}],
#                   ")"}], " ", "p"}]}], ")"}], " ", "z"}], "+",
#             RowBox[{
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"7", " ", "a", " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "26"}], "-",
#                   RowBox[{"2", " ", "a", " ",
#                    RowBox[{"(",
#                     RowBox[{"28", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"13", "+",
#                     RowBox[{"3", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "4"}], "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "114"}], "+",
#                     RowBox[{"25", " ", "a"}]}], ")"}]}]}], ")"}]}]}],
#                     ")"}]}]}], ")"}]}], "+",
#                   RowBox[{"75", " ", "a", " ",
#                    RowBox[{"(",
#                     RowBox[{"1", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"2", "+",
#                     RowBox[{"3", " ", "a"}]}], ")"}]}]}], ")"}], " ", "b"}]}],
#                   ")"}]}], "+",
#                RowBox[{
#                 RowBox[{"(",
#                  RowBox[{"141", "+",
#                   RowBox[{"a", " ",
#                    RowBox[{"(",
#                     RowBox[{"201", "+",
#                     RowBox[{"51", " ", "a"}], "-",
#                     RowBox[{"169", " ",
#                     SuperscriptBox["a", "2"]}], "-",
#                     RowBox[{"424", " ",
#                     SuperscriptBox["a", "3"]}], "-",
#                     RowBox[{"3850", " ",
#                     SuperscriptBox["a", "4"]}], "+",
#                     RowBox[{"900", " ",
#                     SuperscriptBox["a", "5"]}], "-",
#                     RowBox[{"315", " ",
#                     RowBox[{"(",
#                     RowBox[{"1", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"2", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"3", "+",
#                     RowBox[{"4", " ", "a"}]}], ")"}]}]}], ")"}]}]}], ")"}],
#                     " ", "b"}]}], ")"}]}]}], ")"}], " ", "p"}]}], ")"}], " ",
#              SuperscriptBox["z", "2"]}]}], ")"}]}], "-",
#          RowBox[{"210", " ",
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"-", "1"}], "+", "a"}], ")"}], " ", "a", " ",
#           RowBox[{"(",
#            RowBox[{"1", "+", "b"}], ")"}], " ",
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"5", " ",
#              SuperscriptBox["a", "2"], " ",
#              RowBox[{"(",
#               RowBox[{"p", "+",
#                RowBox[{"a", " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "4"}], "+",
#                   RowBox[{"3", " ", "p"}]}], ")"}]}]}], ")"}]}], "-",
#             RowBox[{"2", " ", "a", " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"2", " ", "p"}], "+",
#                RowBox[{"a", " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "5"}], "+",
#                   RowBox[{"6", " ", "p"}], "+",
#                   RowBox[{"3", " ", "a", " ",
#                    RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "5"}], "+",
#                     RowBox[{"4", " ", "p"}]}], ")"}]}]}], ")"}]}]}], ")"}],
#              " ", "z"}], "+",
#             RowBox[{
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{
#                 RowBox[{"-", "2"}], " ", "a", " ",
#                 RowBox[{"(",
#                  RowBox[{"1", "+",
#                   RowBox[{"3", " ", "a"}], "+",
#                   RowBox[{"6", " ",
#                    SuperscriptBox["a", "2"]}]}], ")"}]}], "+", "p", "+",
#                RowBox[{"a", " ",
#                 RowBox[{"(",
#                  RowBox[{"3", "+",
#                   RowBox[{"2", " ", "a", " ",
#                    RowBox[{"(",
#                     RowBox[{"3", "+",
#                     RowBox[{"5", " ", "a"}]}], ")"}]}]}], ")"}], " ", "p"}]}],
#                ")"}], " ",
#              SuperscriptBox["z", "2"]}]}], ")"}], " ",
#           RowBox[{"Log", "[",
#            RowBox[{"1", "+", "b"}], "]"}]}]}], ")"}]}]}], "-",
#      RowBox[{
#       FractionBox["1", "1323000"],
#       RowBox[{"a", " ",
#        RowBox[{"(",
#         RowBox[{
#          RowBox[{"b", " ",
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"245", " ",
#              SuperscriptBox["a", "2"], " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{
#                 RowBox[{"-", "420"}], " ", "p"}], "+",
#                RowBox[{"20", " ",
#                 SuperscriptBox["a", "2"], " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "60"}], "+",
#                   RowBox[{"45", " ", "b", " ",
#                    RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "6"}], "+", "p"}], ")"}]}], "+",
#                   RowBox[{"62", " ", "p"}]}], ")"}]}], "+",
#                RowBox[{"9", " ",
#                 SuperscriptBox["a", "5"], " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "195"}], "+",
#                   RowBox[{"148", " ", "p"}]}], ")"}]}], "+",
#                RowBox[{"5", " ",
#                 SuperscriptBox["a", "3"], " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "830"}], "+",
#                   RowBox[{"60", " ", "b", " ",
#                    RowBox[{"(",
#                     RowBox[{"27", "-",
#                     RowBox[{"16", " ", "p"}]}], ")"}]}], "+",
#                   RowBox[{"193", " ", "p"}]}], ")"}]}], "+",
#                RowBox[{"150", " ", "a", " ",
#                 RowBox[{"(",
#                  RowBox[{"4", "+",
#                   RowBox[{
#                    RowBox[{"(",
#                     RowBox[{"5", "+",
#                     RowBox[{"12", " ", "b"}]}], ")"}], " ", "p"}]}], ")"}]}],
#                "+",
#                RowBox[{"2", " ",
#                 SuperscriptBox["a", "4"], " ",
#                 RowBox[{"(",
#                  RowBox[{"3725", "-",
#                   RowBox[{"2322", " ", "p"}], "+",
#                   RowBox[{"225", " ", "b", " ",
#                    RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "4"}], "+",
#                     RowBox[{"3", " ", "p"}]}], ")"}]}]}], ")"}]}]}], ")"}]}],
#             "-",
#             RowBox[{"14", " ", "a", " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"35", " ", "a", " ",
#                 RowBox[{"(",
#                  RowBox[{"420", "+",
#                   RowBox[{"a", " ",
#                    RowBox[{"(",
#                     RowBox[{
#                     RowBox[{
#                     RowBox[{"-", "150"}], " ",
#                     RowBox[{"(",
#                     RowBox[{"5", "+",
#                     RowBox[{"12", " ", "b"}]}], ")"}]}], "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{
#                     RowBox[{"-", "20"}], " ",
#                     RowBox[{"(",
#                     RowBox[{"62", "+",
#                     RowBox[{"45", " ", "b"}]}], ")"}]}], "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "965"}], "+",
#                     RowBox[{"4800", " ", "b"}], "-",
#                     RowBox[{"18", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "258"}], "+",
#                     RowBox[{"74", " ", "a"}], "+",
#                     RowBox[{"75", " ", "b"}]}], ")"}]}]}], ")"}]}]}],
#                     ")"}]}]}], ")"}]}]}], ")"}]}], "+",
#                RowBox[{
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "10920"}], "+",
#                   RowBox[{"2", " ", "a", " ",
#                    RowBox[{"(",
#                     RowBox[{"9030", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"10360", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"7805", "+",
#                     RowBox[{"6", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{"1008", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "9688"}], "+",
#                     RowBox[{"3125", " ", "a"}]}], ")"}]}]}], ")"}]}]}],
#                     ")"}]}]}], ")"}]}]}], ")"}]}], "+",
#                   RowBox[{"525", " ", "a", " ",
#                    RowBox[{"(",
#                     RowBox[{"60", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"30", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"20", "+",
#                     RowBox[{"9", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "25"}], "+",
#                     RowBox[{"8", " ", "a"}]}], ")"}]}]}], ")"}]}]}],
#                     ")"}]}]}], ")"}], " ", "b"}]}], ")"}], " ", "p"}]}],
#               ")"}], " ", "z"}], "+",
#             RowBox[{
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"7", " ", "a", " ",
#                 RowBox[{"(",
#                  RowBox[{"10920", "-",
#                   RowBox[{"2", " ", "a", " ",
#                    RowBox[{"(",
#                     RowBox[{"9030", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"10360", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"7805", "+",
#                     RowBox[{"6", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{"1008", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "9688"}], "+",
#                     RowBox[{"3125", " ", "a"}]}], ")"}]}]}], ")"}]}]}],
#                     ")"}]}]}], ")"}]}]}], ")"}]}], "-",
#                   RowBox[{"525", " ", "a", " ",
#                    RowBox[{"(",
#                     RowBox[{"60", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"30", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"20", "+",
#                     RowBox[{"9", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "25"}], "+",
#                     RowBox[{"8", " ", "a"}]}], ")"}]}]}], ")"}]}]}],
#                     ")"}]}]}], ")"}], " ", "b"}]}], ")"}]}], "+",
#                RowBox[{
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "59220"}], "+",
#                   RowBox[{"a", " ",
#                    RowBox[{"(",
#                     RowBox[{"92610", "+",
#                     RowBox[{"85470", " ", "a"}], "+",
#                     RowBox[{"62685", " ",
#                     SuperscriptBox["a", "2"]}], "+",
#                     RowBox[{"48111", " ",
#                     SuperscriptBox["a", "3"]}], "+",
#                     RowBox[{"38584", " ",
#                     SuperscriptBox["a", "4"]}], "-",
#                     RowBox[{"629500", " ",
#                     SuperscriptBox["a", "5"]}], "+",
#                     RowBox[{"219375", " ",
#                     SuperscriptBox["a", "6"]}], "+",
#                     RowBox[{"2205", " ",
#                     RowBox[{"(",
#                     RowBox[{"60", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"30", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"20", "+",
#                     RowBox[{"a", " ",
#                     RowBox[{"(",
#                     RowBox[{"15", "+",
#                     RowBox[{"4", " ", "a", " ",
#                     RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "72"}], "+",
#                     RowBox[{"25", " ", "a"}]}], ")"}]}]}], ")"}]}]}],
#                     ")"}]}]}], ")"}]}]}], ")"}], " ", "b"}]}], ")"}]}]}],
#                  ")"}], " ", "p"}]}], ")"}], " ",
#              SuperscriptBox["z", "2"]}]}], ")"}]}], "+",
#          RowBox[{"210", " ", "a", " ",
#           RowBox[{"(",
#            RowBox[{"1", "+", "b"}], ")"}], " ",
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{
#              RowBox[{"-", "210"}], " ", "a", " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"p", " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "8"}], "+", "z"}], ")"}]}], "-",
#                RowBox[{"4", " ", "z"}]}], ")"}], " ", "z"}], "-",
#             RowBox[{"420", " ", "p", " ",
#              SuperscriptBox["z", "2"]}], "-",
#             RowBox[{"35", " ",
#              SuperscriptBox["a", "3"], " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"30", " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "8"}], "+", "p"}], ")"}]}], "+",
#                RowBox[{"4", " ",
#                 RowBox[{"(",
#                  RowBox[{"15", "-",
#                   RowBox[{"4", " ", "p"}]}], ")"}], " ", "z"}], "+",
#                RowBox[{
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "8"}], "+",
#                   RowBox[{"3", " ", "p"}]}], ")"}], " ",
#                 SuperscriptBox["z", "2"]}]}], ")"}]}], "+",
#             RowBox[{"14", " ",
#              SuperscriptBox["a", "4"], " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"-", "1500"}], "+",
#                RowBox[{"850", " ", "p"}], "+",
#                RowBox[{"5", " ",
#                 RowBox[{"(",
#                  RowBox[{"340", "-",
#                   RowBox[{"117", " ", "z"}]}], ")"}], " ", "z"}], "+",
#                RowBox[{"6", " ", "p", " ", "z", " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "195"}], "+",
#                   RowBox[{"74", " ", "z"}]}], ")"}]}]}], ")"}]}], "-",
#             RowBox[{"140", " ",
#              SuperscriptBox["a", "2"], " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{
#                 RowBox[{"-", "3"}], " ",
#                 RowBox[{"(",
#                  RowBox[{
#                   RowBox[{"-", "10"}], "+", "z"}], ")"}], " ", "z"}], "+",
#                RowBox[{"p", " ",
#                 RowBox[{"(",
#                  RowBox[{"15", "+",
#                   RowBox[{
#                    RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "6"}], "+", "z"}], ")"}], " ", "z"}]}],
#                  ")"}]}]}], ")"}]}], "+",
#             RowBox[{"30", " ",
#              SuperscriptBox["a", "6"], " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"4", " ", "p", " ",
#                 RowBox[{"(",
#                  RowBox[{"21", "+",
#                   RowBox[{"5", " ", "z", " ",
#                    RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "7"}], "+",
#                     RowBox[{"3", " ", "z"}]}], ")"}]}]}], ")"}]}], "-",
#                RowBox[{"7", " ",
#                 RowBox[{"(",
#                  RowBox[{"15", "+",
#                   RowBox[{"2", " ", "z", " ",
#                    RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "12"}], "+",
#                     RowBox[{"5", " ", "z"}]}], ")"}]}]}], ")"}]}]}], ")"}]}],
#             "-",
#             RowBox[{"7", " ",
#              SuperscriptBox["a", "5"], " ",
#              RowBox[{"(",
#               RowBox[{
#                RowBox[{"-", "2200"}], "+",
#                RowBox[{"18", " ",
#                 RowBox[{"(",
#                  RowBox[{"175", "-",
#                   RowBox[{"68", " ", "z"}]}], ")"}], " ", "z"}], "+",
#                RowBox[{"p", " ",
#                 RowBox[{"(",
#                  RowBox[{"1575", "+",
#                   RowBox[{"8", " ", "z", " ",
#                    RowBox[{"(",
#                     RowBox[{
#                     RowBox[{"-", "306"}], "+",
#                     RowBox[{"125", " ", "z"}]}], ")"}]}]}], ")"}]}]}],
#               ")"}]}]}], ")"}], " ",
#           RowBox[{"Log", "[",
#            RowBox[{"1", "+", "b"}], "]"}]}]}], ")"}]}]}]}],
#     ")"}]}]}]], "Output",
#  CellChangeTimes->{3.908926758747878*^9, 3.909560438641769*^9,
#   3.916738032534252*^9, 3.916738106237895*^9, 3.9168099192522783`*^9,
#   3.916818027481326*^9, 3.9168200167471943`*^9, 3.9168351264249163`*^9,
#   3.9170218407870283`*^9, 3.9757771313416843`*^9, 3.9757773118747883`*^9},
#  CellLabel->"Out[1]=",ExpressionUUID->"e1be7573-1926-4c8a-9541-1eba90f3b18e"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-10"></a>
#
# <details>
# <summary>Original source cell 10; Input; source line 1349; group 9.1</summary>
#
# ```wolfram
# Cell[BoxData[
#  RowBox[{"J2", "=", " ",
#   RowBox[{"FullSimplify", "[",
#    RowBox[{"Integrate", "[",
#     RowBox[{
#      RowBox[{
#       RowBox[{"(",
#        RowBox[{
#         FractionBox[
#          RowBox[{"1", " ", "-", " ",
#           SuperscriptBox["t", "2"]}], "2"], "+",
#         RowBox[{"t", " ",
#          RowBox[{"Log", "[", "t", "]"}]}]}], ")"}],
#       RowBox[{"(",
#        RowBox[{
#         FractionBox["b", "2"], "-",
#         RowBox[{
#          FractionBox[
#           RowBox[{"t", " ",
#            RowBox[{"(",
#             RowBox[{"b", "+", "1"}], ")"}]}], "b"], " ",
#          RowBox[{"Log", "[",
#           RowBox[{"b", "+", "1"}], "]"}]}], "+",
#         FractionBox[
#          RowBox[{"1", " ", "+", " ",
#           SuperscriptBox["t", "2"]}], "2"]}], ")"}],
#       RowBox[{"(",
#        SuperscriptBox["t", "3"], ")"}],
#       SuperscriptBox[
#        RowBox[{"(",
#         RowBox[{"1", "-",
#          RowBox[{"z",
#           RowBox[{"(",
#            RowBox[{"1", "-", "t"}], ")"}]}]}], ")"}], "2"]}], ",",
#      RowBox[{"{",
#       RowBox[{"t", ",", "0", ",", "1"}], "}"}], ",",
#      RowBox[{"Assumptions", "->",
#       RowBox[{
#        RowBox[{"Element", "[",
#         RowBox[{
#          RowBox[{"{",
#           RowBox[{"b", ",", "z"}], "}"}], ",", "Reals"}], "]"}], "&&",
#        RowBox[{
#         RowBox[{"{", "z", "}"}], "<", "1"}]}]}]}], "]"}], "]"}]}]], "Input",
#  CellChangeTimes->{{3.9167379500982203`*^9, 3.916737950175173*^9}, {
#    3.9167379875454016`*^9, 3.9167380063385043`*^9}, 3.9168199327111626`*^9, {
#    3.9170047518612*^9, 3.917004776242995*^9}, {3.9170099305295453`*^9,
#    3.917009950342039*^9}, {3.975777031996714*^9, 3.9757770453822393`*^9}, {
#    3.975777237320094*^9, 3.975777237752049*^9}},
#  CellLabel->"In[2]:=",ExpressionUUID->"df2e4e99-f152-4a88-a27d-4115937c4945"]
# ```
#
# </details>

# %% [markdown]
# <a id="source-11"></a>
#
# <details>
# <summary>Original source cell 11; Output; source line 1400; group 9.2</summary>
#
# ```wolfram
# Cell[BoxData[
#  FractionBox[
#   RowBox[{
#    RowBox[{"b", " ",
#     RowBox[{"(",
#      RowBox[{"6642", "+",
#       RowBox[{"z", " ",
#        RowBox[{"(",
#         RowBox[{
#          RowBox[{"-", "6669"}], "+",
#          RowBox[{"1867", " ", "z"}]}], ")"}]}], "+",
#       RowBox[{"18", " ", "b", " ",
#        RowBox[{"(",
#         RowBox[{"294", "+",
#          RowBox[{"z", " ",
#           RowBox[{"(",
#            RowBox[{
#             RowBox[{"-", "308"}], "+",
#             RowBox[{"89", " ", "z"}]}], ")"}]}]}], ")"}]}]}], ")"}]}], "-",
#    RowBox[{"45", " ",
#     RowBox[{"(",
#      RowBox[{"1", "+", "b"}], ")"}], " ",
#     RowBox[{"(",
#      RowBox[{"112", "+",
#       RowBox[{"z", " ",
#        RowBox[{"(",
#         RowBox[{
#          RowBox[{"-", "104"}], "+",
#          RowBox[{"27", " ", "z"}]}], ")"}]}]}], ")"}], " ",
#     RowBox[{"Log", "[",
#      RowBox[{"1", "+", "b"}], "]"}]}]}],
#   RowBox[{"6350400", " ", "b"}]]], "Output",
#  CellChangeTimes->{3.9170047910081787`*^9, 3.917009955236636*^9,
#   3.9170218474087467`*^9, 3.9757771370165987`*^9, 3.975777315365301*^9},
#  CellLabel->"Out[2]=",ExpressionUUID->"c858e9cb-e9e7-4971-a743-72df3c52c186"]
# ```
#
# </details>
